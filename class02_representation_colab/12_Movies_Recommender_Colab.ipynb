# %% [raw]
# # Recommender Systems using Word Embeddings

# %% [raw]
# ### Loading the dependencies

# %%
# !pip3 install virtualenv
# !virtualenv ai_course_env
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.26.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.16.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (4.3.2)
# Downloading virtualenv-20.26.4-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 35.4 MB/s eta 0:00:00
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.3.8 virtualenv-20.26.4
# created virtual environment CPython3.10.12.final.0-64 in 3317ms
#   creator CPython3Posix(dest=/content/ai_course_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.2, setuptools==74.1.2, wheel==0.44.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/ai_course_env/bin/activate; pip install gensim==3.8
# Out:
# Collecting gensim==3.8
#   Downloading gensim-3.8.0.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 84.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy>=1.11.3 (from gensim==3.8)
#   Using cached numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting scipy>=0.18.1 (from gensim==3.8)
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting six>=1.5.0 (from gensim==3.8)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting smart_open>=1.7.0 (from gensim==3.8)
#   Using cached smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from smart_open>=1.7.0->gensim==3.8)
#   Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Using cached numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 29.3 MB/s eta 0:00:00
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached smart_open-7.0.4-py3-none-any.whl (61 kB)
# Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.0-cp310-cp310-linux_x86_64.whl size=23718068 sha256=a225cc963abf616c706ad05eadf61f3175ac7834f7dfb1812f00571a17077ec9
#   Stored in directory: /root/.cache/pip/wheels/01/ab/bf/07d4e3462e9f8d17d98c2fb5e870d7e9934c8482a32fc3ef41
# Successfully built gensim
# Installing collected packages: wrapt, six, numpy, smart_open, scipy, gensim
# Successfully installed gensim-3.8.0 numpy-2.1.1 scipy-1.14.1 six-1.16.0 smart_open-7.0.4 wrapt-1.16.0

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
import re
import string
import random
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from gensim.models import Word2Vec, KeyedVectors
from gensim.models.phrases import Phrases, Phraser
from matplotlib import pyplot
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [raw]
# ### Getting the dataset

# %%
# mount Google Drive to Colab session
from google.colab import drive
drive.mount('/content/drive')

# copy to session drive ('/content')
# !cp -r /content/drive/MyDrive/IMDB_Dataset.xlsx /content

import os
dataset_path = os.path.abspath(os.getcwd()) + "/" + "IMDB_Dataset.xlsx"
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel(dataset_path, sheet_name = 'Sheet1').drop(['Unnamed: 0'], axis = 1)
df
# Out:
#                    Movie                                            ImgLink  \
# 0          Project Power  https://m.media-amazon.com/images/M/MV5BYzBhOW...
# 1      The Tax Collector  https://m.media-amazon.com/images/M/MV5BMmFmZT...
# 2            Perry Mason  https://m.media-amazon.com/images/M/MV5BMDllMW...
# 3            Yellowstone  https://m.media-amazon.com/images/M/MV5BZjhkNW...
# 4                   Dark  https://m.media-amazon.com/images/M/MV5BZmY2Yz...
# ...                  ...                                                ...
# 9995             Paprika  https://m.media-amazon.com/images/M/MV5BZWMxYz...
# 9996  I'm Alan Partridge  https://m.media-amazon.com/images/M/MV5BODRmYz...
# 9997  Deep in the Valley  https://m.media-amazon.com/images/M/MV5BZmY4M2...
# 9998      The Red Turtle  https://m.media-amazon.com/images/M/MV5BNGZlYz...
# 9999      Sword of Trust  https://m.media-amazon.com/images/M/MV5BYTY4Ym...
#
#                                             Description
# 0     When a pill that gives its users unpredictable...
# 1     A "tax collector" working for a local crime lo...
# 2     In booming 1932 Los Angeles, a down-and-out de...
# 3     A ranching family in Montana faces off against...
# 4     A family saga with a supernatural twist, set i...
# ...                                                 ...
# 9995  A young country girl comes to town and works i...
# 9996  Alan Partridge, a failed television presenter,...
# 9997  A mysterious video booth transports two friend...
# 9998  A man is shipwrecked on a deserted island and ...
# 9999  Cynthia and Mary show up to collect Cynthia's ...
#
# [10000 rows x 3 columns]

# %% [raw]
# ### Text Preprocessing
#
# Cleaning the 'Description' and storing the cleaned description in a new variable called 'Cleaned'.

# %%
# Function for removing ASCII characters
def _removeNonAscii(s):
    return "".join(i for i in s if ord(i)<128)

# Function for converting to lower case
def make_lower_case(text):
    return text.lower()

# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

# Function for removing html
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

df['Cleaned'] = df['Description'].apply(_removeNonAscii)
df['Cleaned'] = df.Cleaned.apply(func = make_lower_case)
df['Cleaned'] = df.Cleaned.apply(func = remove_stop_words)
df['Cleaned'] = df.Cleaned.apply(func = remove_punctuation)
df['Cleaned'] = df.Cleaned.apply(func = remove_html)

# %%
df
# Out:
#                    Movie                                            ImgLink  \
# 0          Project Power  https://m.media-amazon.com/images/M/MV5BYzBhOW...
# 1      The Tax Collector  https://m.media-amazon.com/images/M/MV5BMmFmZT...
# 2            Perry Mason  https://m.media-amazon.com/images/M/MV5BMDllMW...
# 3            Yellowstone  https://m.media-amazon.com/images/M/MV5BZjhkNW...
# 4                   Dark  https://m.media-amazon.com/images/M/MV5BZmY2Yz...
# ...                  ...                                                ...
# 9995             Paprika  https://m.media-amazon.com/images/M/MV5BZWMxYz...
# 9996  I'm Alan Partridge  https://m.media-amazon.com/images/M/MV5BODRmYz...
# 9997  Deep in the Valley  https://m.media-amazon.com/images/M/MV5BZmY4M2...
# 9998      The Red Turtle  https://m.media-amazon.com/images/M/MV5BNGZlYz...
# 9999      Sword of Trust  https://m.media-amazon.com/images/M/MV5BYTY4Ym...
#
#                                             Description  \
# 0     When a pill that gives its users unpredictable...
# 1     A "tax collector" working for a local crime lo...
# 2     In booming 1932 Los Angeles, a down-and-out de...
# 3     A ranching family in Montana faces off against...
# 4     A family saga with a supernatural twist, set i...
# ...                                                 ...
# 9995  A young country girl comes to town and works i...
# 9996  Alan Partridge, a failed television presenter,...
# 9997  A mysterious video booth transports two friend...
# 9998  A man is shipwrecked on a deserted island and ...
# 9999  Cynthia and Mary show up to collect Cynthia's ...
#
#                                                 Cleaned
# 0     pill gives users unpredictable superpowers fiv...
# 1     tax collector working local crime lord finds f...
# 2     booming 1932 los angeles down and out defense ...
# 3     ranching family montana faces others encroachi...
# 4     family saga supernatural twist set german town...
# ...                                                 ...
# 9995  young country girl comes town works brothel or...
# 9996  alan partridge failed television presenter pre...
# 9997  mysterious video booth transports two friends ...
# 9998  man shipwrecked deserted island encounters red...
# 9999  cynthia mary show collect cynthia s inheritanc...
#
# [10000 rows x 4 columns]

# %% [raw]
# ---

# %% [raw]
# # Recommendation Engine
#
# We will be building two recommendation engines, one using Average Word2Vec and the other with TF-IDF Word2Vec word embeddings.

# %% [raw]
# ## Average Word2Vec
#
# We will split the descriptions into words, store it in a 'corpus', and use it for training our Word2vec model.

# %%
# Splitting the description into words

corpus = []
for words in df['Cleaned']:
    corpus.append(words.split())

# %%
corpus
# Out:
# [['pill',
#   'gives',
#   'users',
#   'unpredictable',
#   'superpowers',
#   'five',
#   'minutes',
#   'hits',
#   'streets',
#   'new',
#   'orleans',
#   'teenage',
#   'dealer',
#   'local',
#   'cop',
#   'must',
#   'team',
#   'ex',
#   'soldier',
#   'take',
#   'group',
#   'responsible',
#   'creation'],
#  ['tax',
#   'collector',
#   'working',
#   'local',
#   'crime',
#   'lord',
#   'finds',
#   'family',
#   's',
#   'safety',
#   'compromised',
#   'rival',
#   'boss',
#   'shows',
#   'l',
#   'a',
#   'upends',
#   'business'],
#  ['booming',
#   '1932',
#   'los',
#   'angeles',
#   'down',
#   'and',
#   'out',
#   'defense',
#   'attorney',
#   'takes',
#   'case',
#   'lifetime'],
#  ['ranching', 'family', 'montana', 'faces', 'others', 'encroaching', 'land'],
#  ['family',
#   'saga',
#   'supernatural',
#   'twist',
#   'set',
#   'german',
#   'town',
#   'disappearance',
#   'two',
#   'young',
#   'children',
#   'exposes',
#   'relationships',
#   'among',
#   'four',
#   'families'],
#  ['quinn',
#   'ackerman',
#   's',
#   'admission',
#   'college',
#   'dreams',
#   'depends',
#   'performance',
#   'dance',
#   'competition',
#   'forms',
#   'ragtag',
#   'group',
#   'dancers',
#   'take',
#   'best',
#   'squad',
#   'school',
#   'now',
#   'needs',
#   'learn',
#   'dance'],
#  ['androids',
#   'tasked',
#   'raising',
#   'human',
#   'children',
#   'mysterious',
#   'planet'],
#  ['group',
#   'vigilantes',
#   'set',
#   'take',
#   'corrupt',
#   'superheroes',
#   'abuse',
#   'superpowers'],
#  ['massimo',
#   'member',
#   'sicilian',
#   'mafia',
#   'family',
#   'laura',
#   'sales',
#   'director',
#   'expect',
#   'trip',
#   'sicily',
#   'trying',
#   'save',
#   'relationship',
#   'massimo',
#   'kidnap',
#   'give',
#   '365',
#   'days',
#   'fall',
#   'love',
#   'him'],
#  ['nine',
#   'noble',
#   'families',
#   'fight',
#   'control',
#   'lands',
#   'westeros',
#   'ancient',
#   'enemy',
#   'returns',
#   'dormant',
#   'millennia'],
#  ['missions',
#   'strategic',
#   'homeland',
#   'intervention',
#   'enforcement',
#   'logistics',
#   'division'],
#  ['armed',
#   'one',
#   'word',
#   'tenet',
#   'fighting',
#   'survival',
#   'entire',
#   'world',
#   'protagonist',
#   'journeys',
#   'twilight',
#   'world',
#   'international',
#   'espionage',
#   'mission',
#   'unfold',
#   'something',
#   'beyond',
#   'real',
#   'time'],
#  ['set',
#   'ninety',
#   'seven',
#   'years',
#   'nuclear',
#   'war',
#   'destroyed',
#   'civilization',
#   'spaceship',
#   'housing',
#   'humanity',
#   's',
#   'lone',
#   'survivors',
#   'sends',
#   'one',
#   'hundred',
#   'juvenile',
#   'delinquents',
#   'back',
#   'earth',
#   'hopes',
#   'possibly',
#   're',
#   'populating',
#   'planet'],
#  ['inspired',
#   'life',
#   'fearless',
#   'young',
#   'officer',
#   'made',
#   'history',
#   'becoming',
#   'first',
#   'indian',
#   'female',
#   'air',
#   'force',
#   'officer',
#   'fly',
#   'combat',
#   'zone',
#   '1999',
#   'kargil',
#   'war'],
#  ['scrappy',
#   'feisty',
#   'fiercely',
#   'loyal',
#   'chicago',
#   'family',
#   'makes',
#   'apologies'],
#  ['young',
#   'chinese',
#   'maiden',
#   'disguises',
#   'male',
#   'warrior',
#   'order',
#   'save',
#   'father',
#   'live',
#   'action',
#   'feature',
#   'film',
#   'based',
#   'disney',
#   's',
#   'mulan'],
#  ['lucifer',
#   'morningstar',
#   'decided',
#   'he',
#   's',
#   'enough',
#   'dutiful',
#   'servant',
#   'hell',
#   'decides',
#   'spend',
#   'time',
#   'earth',
#   'better',
#   'understand',
#   'humanity',
#   'settles',
#   'los',
#   'angeles',
#   'city',
#   'angels'],
#  ['sinister',
#   'characters',
#   'converge',
#   'around',
#   'young',
#   'man',
#   'devoted',
#   'protecting',
#   'loves',
#   'postwar',
#   'backwoods',
#   'town',
#   'teeming',
#   'corruption',
#   'brutality'],
#  ['american',
#   'astronaut',
#   'struggles',
#   'leaving',
#   'husband',
#   'daughter',
#   'behind',
#   'embark',
#   'dangerous',
#   'mission',
#   'international',
#   'space',
#   'crew'],
#  ['mockumentary',
#   'group',
#   'typical',
#   'office',
#   'workers',
#   'workday',
#   'consists',
#   'ego',
#   'clashes',
#   'inappropriate',
#   'behavior',
#   'tedium'],
#  ['drama',
#   'centered',
#   'personal',
#   'professional',
#   'lives',
#   'five',
#   'surgical',
#   'interns',
#   'supervisors'],
#  ['detective',
#   'investigates',
#   'death',
#   'patriarch',
#   'eccentric',
#   'combative',
#   'family'],
#  ['high',
#   'school',
#   'chemistry',
#   'teacher',
#   'diagnosed',
#   'inoperable',
#   'lung',
#   'cancer',
#   'turns',
#   'manufacturing',
#   'selling',
#   'methamphetamine',
#   'order',
#   'secure',
#   'family',
#   's',
#   'future'],
#  ['two',
#   'brothers',
#   'follow',
#   'father',
#   's',
#   'footsteps',
#   'hunters',
#   'fighting',
#   'evil',
#   'supernatural',
#   'beings',
#   'many',
#   'kinds',
#   'including',
#   'monsters',
#   'demons',
#   'gods',
#   'roam',
#   'earth'],
#  ['immigrant',
#   'worker',
#   'pickle',
#   'factory',
#   'accidentally',
#   'preserved',
#   '100',
#   'years',
#   'wakes',
#   'modern',
#   'day',
#   'brooklyn'],
#  ['covert',
#   'team',
#   'immortal',
#   'mercenaries',
#   'suddenly',
#   'exposed',
#   'must',
#   'fight',
#   'keep',
#   'identity',
#   'secret',
#   'unexpected',
#   'new',
#   'member',
#   'discovered'],
#  ['cases',
#   'f',
#   'b',
#   'i',
#   'behavioral',
#   'analysis',
#   'unit',
#   'b',
#   'a',
#   'u',
#   'elite',
#   'group',
#   'profilers',
#   'analyze',
#   'nation',
#   's',
#   'dangerous',
#   'serial',
#   'killers',
#   'individual',
#   'heinous',
#   'crimes',
#   'effort',
#   'anticipate',
#   'next',
#   'moves',
#   'strike',
#   'again'],
#  ['vikings',
#   'transports',
#   'us',
#   'brutal',
#   'mysterious',
#   'world',
#   'ragnar',
#   'lothbrok',
#   'viking',
#   'warrior',
#   'farmer',
#   'yearns',
#   'explore',
#   'raid',
#   'distant',
#   'shores',
#   'across',
#   'ocean'],
#  ['seemingly',
#   'cold',
#   'passionate',
#   'policewoman',
#   'goes',
#   'head',
#   'head',
#   'seemingly',
#   'passionate',
#   'father',
#   'fact',
#   'cold',
#   'serialist',
#   'procedural',
#   'belfast',
#   'thing',
#   'share',
#   'common',
#   'complexity'],
#  ['teenage',
#   'sorceress',
#   'named',
#   'nimue',
#   'encounters',
#   'young',
#   'arthur',
#   'quest',
#   'find',
#   'powerful',
#   'ancient',
#   'sword'],
#  ['suspended',
#   'lawyer',
#   'forced',
#   'enroll',
#   'community',
#   'college',
#   'eccentric',
#   'staff',
#   'student',
#   'body'],
#  ['rich',
#   'video',
#   'store',
#   'magnate',
#   'johnny',
#   'rose',
#   'family',
#   'suddenly',
#   'find',
#   'broke',
#   'forced',
#   'leave',
#   'pampered',
#   'lives',
#   'regroup',
#   'schitt',
#   's',
#   'creek'],
#  ['brutal',
#   'virus',
#   'wipes',
#   'population',
#   'two',
#   'young',
#   'siblings',
#   'embark',
#   'perilous',
#   'search',
#   'safety'],
#  ['retired',
#   'mma',
#   'fighter',
#   'turned',
#   'trainer',
#   'juggles',
#   'keeping',
#   'mixed',
#   'martial',
#   'arts',
#   'gym',
#   'running',
#   'keeping',
#   'family',
#   'united'],
#  ['newspaper',
#   'illustrator',
#   'john',
#   'moore',
#   'meets',
#   'criminal',
#   'psychologist',
#   'alienist',
#   'dr',
#   'laszlo',
#   'kreizler',
#   'investigate',
#   'serial',
#   'killer',
#   'new',
#   'york',
#   'late',
#   '19th',
#   'century'],
#  ['emotional',
#   'journey',
#   'two',
#   'hopelessly',
#   'love',
#   'youngsters',
#   'young',
#   'girl',
#   'kizie',
#   'suffering',
#   'cancer',
#   'boy',
#   'manny',
#   'meets',
#   'support',
#   'group'],
#  ['adventures',
#   'idealistic',
#   'mad',
#   'scientist',
#   'field',
#   'team',
#   'superpowered',
#   'outcasts'],
#  ['magistrate',
#   'working',
#   'distant',
#   'outpost',
#   'begins',
#   'question',
#   'loyalty',
#   'empire'],
#  ['follows',
#   'personal',
#   'professional',
#   'lives',
#   'six',
#   'twenty',
#   'thirty',
#   'something',
#   'year',
#   'old',
#   'friends',
#   'living',
#   'manhattan'],
#  ['sheriff',
#   'deputy',
#   'rick',
#   'grimes',
#   'wakes',
#   'coma',
#   'learn',
#   'world',
#   'ruins',
#   'must',
#   'lead',
#   'group',
#   'survivors',
#   'stay',
#   'alive'],
#  ['financial',
#   'advisor',
#   'drags',
#   'family',
#   'chicago',
#   'missouri',
#   'ozarks',
#   'must',
#   'launder',
#   'money',
#   'appease',
#   'drug',
#   'boss'],
#  ['real',
#   'life',
#   'one',
#   'america',
#   's',
#   'foremost',
#   'founding',
#   'fathers',
#   'first',
#   'secretary',
#   'treasury',
#   'alexander',
#   'hamilton',
#   'captured',
#   'live',
#   'broadway',
#   'richard',
#   'rodgers',
#   'theater',
#   'original',
#   'broadway',
#   'cast'],
#  ['gangster',
#   'family',
#   'epic',
#   'set',
#   '1919',
#   'birmingham',
#   'england',
#   'centered',
#   'gang',
#   'sew',
#   'razor',
#   'blades',
#   'peaks',
#   'caps',
#   'fierce',
#   'boss',
#   'tommy',
#   'shelby'],
#  ['young',
#   'boy',
#   'disappears',
#   'mother',
#   'police',
#   'chief',
#   'friends',
#   'must',
#   'confront',
#   'terrifying',
#   'supernatural',
#   'forces',
#   'order',
#   'get',
#   'back'],
#  ['three',
#   'best',
#   'friends',
#   'embark',
#   'road',
#   'trip',
#   'heavy',
#   'metal',
#   'show',
#   'bond',
#   'three',
#   'aspiring',
#   'musicians',
#   'head',
#   'one',
#   'girls',
#   'country',
#   'home',
#   'after',
#   'party'],
#  ['trying',
#   'put',
#   'life',
#   'back',
#   'together',
#   'death',
#   'husband',
#   'libby',
#   'children',
#   'move',
#   'estranged',
#   'aunt',
#   's',
#   'goat',
#   'farm',
#   'central',
#   'texas'],
#  ['three',
#   'different',
#   'related',
#   'families',
#   'face',
#   'trials',
#   'tribulations',
#   'uniquely',
#   'comedic',
#   'ways'],
#  ['indian',
#   'classical',
#   'singer',
#   'radhe',
#   'pop',
#   'star',
#   'tamanna',
#   'despite',
#   'contrasting',
#   'personalities',
#   'two',
#   'set',
#   'together',
#   'journey',
#   'self',
#   'discovery',
#   'see',
#   'opposites',
#   'though',
#   'might',
#   'attract',
#   'also',
#   'adapt',
#   'go',
#   'long',
#   'haul'],
#  ['gotham',
#   'city',
#   'mentally',
#   'troubled',
#   'comedian',
#   'arthur',
#   'fleck',
#   'disregarded',
#   'mistreated',
#   'society',
#   'embarks',
#   'downward',
#   'spiral',
#   'revolution',
#   'bloody',
#   'crime',
#   'path',
#   'brings',
#   'face',
#   'to',
#   'face',
#   'alter',
#   'ego',
#   'joker'],
#  ['feature',
#   'adaptation',
#   'frank',
#   'herbert',
#   's',
#   'science',
#   'fiction',
#   'novel',
#   'son',
#   'noble',
#   'family',
#   'entrusted',
#   'protection',
#   'valuable',
#   'asset',
#   'vital',
#   'element',
#   'galaxy'],
#  ['biker',
#   'struggles',
#   'balance',
#   'father',
#   'involved',
#   'outlaw',
#   'motorcycle',
#   'club'],
#  ['various',
#   'chronicles',
#   'deception',
#   'intrigue',
#   'murder',
#   'around',
#   'frozen',
#   'minnesota',
#   'yet',
#   'tales',
#   'mysteriously',
#   'lead',
#   'back',
#   'one',
#   'way',
#   'another',
#   'fargo',
#   'north',
#   'dakota'],
#  ['young',
#   'boy',
#   'hitler',
#   's',
#   'army',
#   'finds',
#   'mother',
#   'hiding',
#   'jewish',
#   'girl',
#   'home'],
#  ['unusual',
#   'group',
#   'robbers',
#   'attempt',
#   'carry',
#   'perfect',
#   'robbery',
#   'spanish',
#   'history',
#   'stealing',
#   '2',
#   '4',
#   'billion',
#   'euros',
#   'royal',
#   'mint',
#   'spain'],
#  ['zak',
#   'runs',
#   'away',
#   'care',
#   'home',
#   'make',
#   'dream',
#   'becoming',
#   'wrestler',
#   'come',
#   'true'],
#  ['three',
#   'suburban',
#   'mothers',
#   'suddenly',
#   'find',
#   'desperate',
#   'circumstances',
#   'decide',
#   'stop',
#   'playing',
#   'safe',
#   'risk',
#   'everything',
#   'take',
#   'power',
#   'back'],
#  ['orphaned',
#   'girl',
#   'discovers',
#   'magical',
#   'garden',
#   'hidden',
#   'strict',
#   'uncle',
#   's',
#   'estate'],
#  ['carefree',
#   'nyles',
#   'reluctant',
#   'maid',
#   'honor',
#   'sarah',
#   'chance',
#   'encounter',
#   'palm',
#   'springs',
#   'wedding',
#   'things',
#   'get',
#   'complicated',
#   'unable',
#   'escape',
#   'venue',
#   'themselves',
#   'other'],
#  ['bad',
#   'break',
#   'up',
#   'jess',
#   'offbeat',
#   'young',
#   'woman',
#   'moves',
#   'apartment',
#   'loft',
#   'three',
#   'single',
#   'men',
#   'although',
#   'find',
#   'behavior',
#   'unusual',
#   'men',
#   'support',
#   'time'],
#  ['woman',
#   'moves',
#   'apartment',
#   'across',
#   'hall',
#   'two',
#   'brilliant',
#   'socially',
#   'awkward',
#   'physicists',
#   'shows',
#   'little',
#   'know',
#   'life',
#   'outside',
#   'laboratory'],
#  ['new',
#   'jersey',
#   'mob',
#   'boss',
#   'tony',
#   'soprano',
#   'deals',
#   'personal',
#   'professional',
#   'issues',
#   'home',
#   'business',
#   'life',
#   'affect',
#   'mental',
#   'state',
#   'leading',
#   'seek',
#   'professional',
#   'psychiatric',
#   'counseling'],
#  ['run',
#   'drug',
#   'deal',
#   'gone',
#   'bad',
#   'brilliant',
#   'college',
#   'dropout',
#   'mike',
#   'ross',
#   'finds',
#   'working',
#   'harvey',
#   'specter',
#   'one',
#   'new',
#   'york',
#   'city',
#   's',
#   'best',
#   'lawyers'],
#  ['aspiring',
#   'musicians',
#   'lars',
#   'sigrit',
#   'given',
#   'opportunity',
#   'represent',
#   'country',
#   'world',
#   's',
#   'biggest',
#   'song',
#   'competition',
#   'finally',
#   'chance',
#   'prove',
#   'dream',
#   'worth',
#   'dream',
#   'worth',
#   'fighting',
#   'for'],
#  ['several',
#   'months',
#   'u',
#   's',
#   'entry',
#   'world',
#   'war',
#   'ii',
#   'inexperienced',
#   'u',
#   's',
#   'navy',
#   'commander',
#   'must',
#   'lead',
#   'allied',
#   'convoy',
#   'stalked',
#   'german',
#   'submarine',
#   'wolf',
#   'pack'],
#  ['look',
#   'life',
#   'group',
#   'high',
#   'school',
#   'students',
#   'grapple',
#   'issues',
#   'drugs',
#   'sex',
#   'violence'],
#  ['brooklyn',
#   'nine',
#   'nine',
#   'follows',
#   'exploits',
#   'hilarious',
#   'det',
#   'jake',
#   'peralta',
#   'diverse',
#   'lovable',
#   'colleagues',
#   'police',
#   'nypd',
#   's',
#   '99th',
#   'precinct'],
#  ['american',
#   'security',
#   'guard',
#   'richard',
#   'jewell',
#   'saves',
#   'many',
#   'lives',
#   'exploding',
#   'bomb',
#   '1996',
#   'olympics',
#   'vilified',
#   'journalists',
#   'press',
#   'falsely',
#   'reported',
#   'terrorist'],
#  ['english',
#   'combat',
#   'nurse',
#   '1945',
#   'mysteriously',
#   'swept',
#   'back',
#   'time',
#   '1743'],
#  ['alfred',
#   'great',
#   'defends',
#   'kingdom',
#   'norse',
#   'invaders',
#   'uhtred',
#   'born',
#   'saxon',
#   'raised',
#   'vikings',
#   'seeks',
#   'claim',
#   'ancestral',
#   'birthright'],
#  ['teenager',
#   'courtney',
#   'whitmore',
#   'joins',
#   'justice',
#   'society',
#   'america',
#   'based',
#   'character',
#   'dc',
#   'comics'],
#  ['group',
#   'ambitious',
#   'misfits',
#   'try',
#   'escape',
#   'harsh',
#   'realities',
#   'high',
#   'school',
#   'joining',
#   'glee',
#   'club',
#   'headed',
#   'passionate',
#   'spanish',
#   'teacher'],
#  ['faded',
#   'television',
#   'actor',
#   'stunt',
#   'double',
#   'strive',
#   'achieve',
#   'fame',
#   'success',
#   'final',
#   'years',
#   'hollywood',
#   's',
#   'golden',
#   'age',
#   '1969',
#   'los',
#   'angeles'],
#  ['trials',
#   'tribulations',
#   'criminal',
#   'lawyer',
#   'jimmy',
#   'mcgill',
#   'time',
#   'established',
#   'strip',
#   'mall',
#   'law',
#   'office',
#   'albuquerque',
#   'new',
#   'mexico'],
#  ['anthology',
#   'series',
#   'exploring',
#   'twisted',
#   'high',
#   'tech',
#   'multiverse',
#   'humanity',
#   's',
#   'greatest',
#   'innovations',
#   'darkest',
#   'instincts',
#   'collide'],
#  ['andy',
#   'urging',
#   'former',
#   'mentor',
#   'magic',
#   'camp',
#   'owner',
#   'roy',
#   'preston',
#   'returns',
#   'counselor',
#   'camp',
#   'youth',
#   'hoping',
#   'reignite',
#   'career'],
#  ['anthology',
#   'series',
#   'centering',
#   'different',
#   'characters',
#   'locations',
#   'including',
#   'house',
#   'murderous',
#   'past',
#   'insane',
#   'asylum',
#   'witch',
#   'coven',
#   'freak',
#   'show',
#   'circus',
#   'haunted',
#   'hotel',
#   'possessed',
#   'farmhouse',
#   'cult',
#   'apocalypse',
#   'slasher',
#   'summer',
#   'camp'],
#  ['series',
#   'follows',
#   'special',
#   'victims',
#   'unit',
#   'specially',
#   'trained',
#   'squad',
#   'detectives',
#   'n',
#   'y',
#   'p',
#   'd',
#   'investigate',
#   'sexually',
#   'related',
#   'crimes'],
#  ['pragmatic',
#   'paleontologist',
#   'visiting',
#   'almost',
#   'complete',
#   'theme',
#   'park',
#   'tasked',
#   'protecting',
#   'couple',
#   'kids',
#   'power',
#   'failure',
#   'causes',
#   'park',
#   's',
#   'cloned',
#   'dinosaurs',
#   'run',
#   'loose'],
#  ['sequel',
#   '2018',
#   's',
#   'kissing',
#   'booth',
#   'high',
#   'school',
#   'senior',
#   'elle',
#   'juggles',
#   'long',
#   'distance',
#   'relationship',
#   'dreamy',
#   'boyfriend',
#   'noah',
#   'college',
#   'applications',
#   'new',
#   'friendship',
#   'handsome',
#   'classmate',
#   'could',
#   'change',
#   'everything'],
#  ['entering',
#   'mythical',
#   'world',
#   'monkey',
#   'king',
#   'young',
#   'monk',
#   'group',
#   'disciples',
#   'journey',
#   'collect',
#   'scrolls',
#   'buddhist',
#   'wisdom'],
#  ['new',
#   'fbi',
#   'profiler',
#   'elizabeth',
#   'keen',
#   'entire',
#   'life',
#   'uprooted',
#   'mysterious',
#   'criminal',
#   'raymond',
#   'reddington',
#   'eluded',
#   'capture',
#   'decades',
#   'turns',
#   'insists',
#   'speaking',
#   'her'],
#  ['war',
#   'torn',
#   'world',
#   'elemental',
#   'magic',
#   'young',
#   'boy',
#   'reawakens',
#   'undertake',
#   'dangerous',
#   'mystic',
#   'quest',
#   'fulfill',
#   'destiny',
#   'avatar',
#   'bring',
#   'peace',
#   'world'],
#  ['lives',
#   'loves',
#   'dangers',
#   'disasters',
#   'town',
#   'mystic',
#   'falls',
#   'virginia',
#   'creatures',
#   'unspeakable',
#   'horror',
#   'lurk',
#   'beneath',
#   'town',
#   'teenage',
#   'girl',
#   'suddenly',
#   'torn',
#   'two',
#   'vampire',
#   'brothers'],
#  ['american',
#   'expat',
#   'tries',
#   'sell',
#   'highly',
#   'profitable',
#   'marijuana',
#   'empire',
#   'london',
#   'triggering',
#   'plots',
#   'schemes',
#   'bribery',
#   'blackmail',
#   'attempt',
#   'steal',
#   'domain',
#   'him'],
#  ['travels',
#   'lone',
#   'bounty',
#   'hunter',
#   'outer',
#   'reaches',
#   'galaxy',
#   'far',
#   'authority',
#   'new',
#   'republic'],
#  ['cases',
#   'naval',
#   'criminal',
#   'investigative',
#   'service',
#   's',
#   'washington',
#   'd',
#   'c',
#   'major',
#   'case',
#   'response',
#   'team',
#   'led',
#   'special',
#   'agent',
#   'leroy',
#   'jethro',
#   'gibbs'],
#  ['story',
#   'fred',
#   'hampton',
#   'chairman',
#   'illinois',
#   'black',
#   'panther',
#   'party',
#   'fateful',
#   'betrayal',
#   'fbi',
#   'informant',
#   'william',
#   'o',
#   'neal'],
#  ['confrontation',
#   'unstable',
#   'man',
#   'intersection',
#   'woman',
#   'becomes',
#   'target',
#   'rage'],
#  ['survivors',
#   'plane',
#   'crash',
#   'forced',
#   'work',
#   'together',
#   'order',
#   'survive',
#   'seemingly',
#   'deserted',
#   'tropical',
#   'island'],
#  ['young',
#   'african',
#   'american',
#   'travels',
#   'across',
#   'u',
#   's',
#   '1950s',
#   'search',
#   'missing',
#   'father'],
#  ['set',
#   'dystopian',
#   'future',
#   'woman',
#   'forced',
#   'live',
#   'concubine',
#   'fundamentalist',
#   'theocratic',
#   'dictatorship'],
#  ['absurd',
#   'antics',
#   'indiana',
#   'town',
#   's',
#   'public',
#   'officials',
#   'pursue',
#   'sundry',
#   'projects',
#   'make',
#   'city',
#   'better',
#   'place'],
#  ['five',
#   'friends',
#   'exploring',
#   'remote',
#   'cave',
#   'system',
#   'northern',
#   'australia',
#   'find',
#   'threatened',
#   'hungry',
#   'crocodile'],
#  ['based',
#   '2014',
#   'romance',
#   'novel',
#   'name',
#   'follows',
#   'love',
#   'life',
#   'two',
#   'young',
#   'adults'],
#  ['fast',
#   'forward',
#   '1980s',
#   'wonder',
#   'woman',
#   's',
#   'next',
#   'big',
#   'screen',
#   'adventure',
#   'finds',
#   'facing',
#   'two',
#   'all',
#   'new',
#   'foes',
#   'max',
#   'lord',
#   'cheetah'],
#  ['set',
#   '1960s',
#   'show',
#   'follows',
#   'endeavour',
#   'morse',
#   'early',
#   'years',
#   'police',
#   'constable',
#   'working',
#   'alongside',
#   'senior',
#   'partner',
#   'di',
#   'fred',
#   'thursday',
#   'morse',
#   'engages',
#   'number',
#   'investigations',
#   'around',
#   'oxford'],
#  ['two',
#   'couples',
#   'rent',
#   'vacation',
#   'home',
#   'celebratory',
#   'weekend',
#   'get',
#   'away'],
#  ['murphy',
#   'american',
#   'living',
#   'paris',
#   'enters',
#   'highly',
#   'sexually',
#   'emotionally',
#   'charged',
#   'relationship',
#   'unstable',
#   'electra',
#   'unaware',
#   'effect',
#   'relationship',
#   'invite',
#   'pretty',
#   'neighbor',
#   'bed'],
#  ['drama',
#   'investigations',
#   'ac',
#   '12',
#   'controversial',
#   'police',
#   'anticorruption',
#   'unit'],
#  ['thief',
#   'steals',
#   'corporate',
#   'secrets',
#   'use',
#   'dream',
#   'sharing',
#   'technology',
#   'given',
#   'inverse',
#   'task',
#   'planting',
#   'idea',
#   'mind',
#   'c',
#   'e',
#   'o'],
#  ['devastating',
#   'events',
#   'avengers',
#   'infinity',
#   'war',
#   '2018',
#   'universe',
#   'ruins',
#   'help',
#   'remaining',
#   'allies',
#   'avengers',
#   'assemble',
#   'order',
#   'reverse',
#   'thanos',
#   'actions',
#   'restore',
#   'balance',
#   'universe'],
#  ['elite',
#   'real',
#   'estate',
#   'brokers',
#   'oppenheim',
#   'group',
#   'sell',
#   'luxe',
#   'life',
#   'affluent',
#   'buyers',
#   'la',
#   'drama',
#   'ramps',
#   'new',
#   'agent',
#   'joins',
#   'team'],
#  ['succession',
#   'follows',
#   'dysfunctional',
#   'american',
#   'global',
#   'media',
#   'family'],
#  ['explores',
#   'early',
#   'relationship',
#   'renowned',
#   'psychiatrist',
#   'hannibal',
#   'lecter',
#   'patient',
#   'young',
#   'fbi',
#   'criminal',
#   'profiler',
#   'haunted',
#   'ability',
#   'empathize',
#   'serial',
#   'killers'],
#  ['set',
#   'intersection',
#   'near',
#   'future',
#   'reimagined',
#   'past',
#   'explore',
#   'world',
#   'every',
#   'human',
#   'appetite',
#   'indulged',
#   'without',
#   'consequence'],
#  ['follows',
#   'political',
#   'rivalries',
#   'romance',
#   'queen',
#   'elizabeth',
#   'ii',
#   's',
#   'reign',
#   'events',
#   'shaped',
#   'second',
#   'half',
#   'twentieth',
#   'century'],
#  ['years',
#   'following',
#   'events',
#   'shining',
#   '1980',
#   'now',
#   'adult',
#   'dan',
#   'torrance',
#   'must',
#   'protect',
#   'young',
#   'girl',
#   'similar',
#   'powers',
#   'cult',
#   'known',
#   'true',
#   'knot',
#   'prey',
#   'children',
#   'powers',
#   'remain',
#   'immortal'],
#  ['set',
#   'almost',
#   '100',
#   'years',
#   'captain',
#   'kirk',
#   's',
#   'five',
#   'year',
#   'mission',
#   'new',
#   'generation',
#   'starfleet',
#   'officers',
#   'set',
#   'u',
#   's',
#   's',
#   'enterprise',
#   'd',
#   'mission',
#   'go',
#   'one',
#   'gone',
#   'before'],
#  ['high',
#   'school',
#   'student',
#   'forced',
#   'confront',
#   'secret',
#   'crush',
#   'kissing',
#   'booth'],
#  ['adventures',
#   'time',
#   'space',
#   'alien',
#   'adventurer',
#   'known',
#   'doctor',
#   'companions',
#   'planet',
#   'earth'],
#  ['greed',
#   'class',
#   'discrimination',
#   'threaten',
#   'newly',
#   'formed',
#   'symbiotic',
#   'relationship',
#   'wealthy',
#   'park',
#   'family',
#   'destitute',
#   'kim',
#   'clan'],
#  ['thirsty',
#   'following',
#   'kurt',
#   'kunkle',
#   'rideshare',
#   'driver',
#   'figured',
#   'deadly',
#   'plan',
#   'go',
#   'viral'],
#  ['geralt',
#   'rivia',
#   'solitary',
#   'monster',
#   'hunter',
#   'struggles',
#   'find',
#   'place',
#   'world',
#   'people',
#   'often',
#   'prove',
#   'wicked',
#   'beasts'],
#  ['antisocial',
#   'maverick',
#   'doctor',
#   'specializes',
#   'diagnostic',
#   'medicine',
#   'whatever',
#   'takes',
#   'solve',
#   'puzzling',
#   'cases',
#   'come',
#   'way',
#   'using',
#   'crack',
#   'team',
#   'doctors',
#   'wits'],
#  ['third', 'installment', 'dreamwork', 's', 'tales', 'arcadia', 'trilogy'],
#  ['baltimore',
#   'drug',
#   'scene',
#   'seen',
#   'eyes',
#   'drug',
#   'dealers',
#   'law',
#   'enforcement'],
#  ['young', 'blind', 'woman', 'tries', 'solve', 'friend', 's', 'murder'],
#  ['young',
#   'woman',
#   'destined',
#   'slay',
#   'vampires',
#   'demons',
#   'infernal',
#   'creatures',
#   'deals',
#   'life',
#   'fighting',
#   'evil',
#   'help',
#   'friends'],
#  ['miami',
#   'detectives',
#   'mike',
#   'lowrey',
#   'marcus',
#   'burnett',
#   'must',
#   'face',
#   'mother',
#   'and',
#   'son',
#   'pair',
#   'drug',
#   'lords',
#   'wreak',
#   'vengeful',
#   'havoc',
#   'city'],
#  ['studying',
#   'effects',
#   'climate',
#   'change',
#   'coast',
#   'mozambique',
#   'marine',
#   'biologist',
#   'team',
#   'confront',
#   'three',
#   'genetically',
#   'enhanced',
#   'bull',
#   'sharks',
#   'now',
#   'new',
#   'bloodbath',
#   'waiting',
#   'happen',
#   'name',
#   'science',
#   'humans',
#   'never',
#   'learn'],
#  ['father',
#   'recounts',
#   'children',
#   'series',
#   'flashbacks',
#   'journey',
#   'four',
#   'best',
#   'friends',
#   'took',
#   'leading',
#   'meeting',
#   'mother'],
#  ['bipolar',
#   'cia',
#   'operative',
#   'becomes',
#   'convinced',
#   'prisoner',
#   'war',
#   'turned',
#   'al',
#   'qaeda',
#   'planning',
#   'carry',
#   'terrorist',
#   'attack',
#   'american',
#   'soil'],
#  ['day',
#   'mild',
#   'mannered',
#   'dexter',
#   'blood',
#   'spatter',
#   'analyst',
#   'miami',
#   'police',
#   'night',
#   'serial',
#   'killer',
#   'targets',
#   'murderers'],
#  ['small',
#   'team',
#   'u',
#   's',
#   'soldiers',
#   'battle',
#   'hundreds',
#   'taliban',
#   'fighters',
#   'afghanistan'],
#  ['bohemian',
#   'artist',
#   'travels',
#   'london',
#   'italy',
#   'estranged',
#   'son',
#   'sell',
#   'house',
#   'inherited',
#   'late',
#   'wife'],
#  ['newly',
#   'married',
#   'couple',
#   's',
#   'life',
#   'falls',
#   'jeopardy',
#   'wife',
#   'goes',
#   'missing',
#   'mysterious',
#   'circumstances'],
#  ['five',
#   'young',
#   'mutants',
#   'discovering',
#   'abilities',
#   'held',
#   'secret',
#   'facility',
#   'will',
#   'fight',
#   'escape',
#   'past',
#   'sins',
#   'save',
#   'themselves'],
#  ['anthology',
#   'series',
#   'examines',
#   'ordinary',
#   'people',
#   'commit',
#   'brutal',
#   'crimes'],
#  ['anthology',
#   'series',
#   'season',
#   'based',
#   'true',
#   'crime',
#   'story',
#   'featuring',
#   'epic',
#   'tale',
#   'love',
#   'gone',
#   'wrong'],
#  ['young',
#   'woman',
#   'troubled',
#   'past',
#   'drawn',
#   'small',
#   'town',
#   'maine',
#   'fairy',
#   'tales',
#   'believed'],
#  ['dramedy',
#   'centering',
#   'around',
#   'relationship',
#   'thirtysomething',
#   'single',
#   'mother',
#   'teen',
#   'daughter',
#   'living',
#   'stars',
#   'hollow',
#   'connecticut'],
#  ['brothel',
#   'owner',
#   'margaret',
#   'wells',
#   'struggles',
#   'raise',
#   'daughters',
#   'london',
#   '18th',
#   'century'],
#  ['two',
#   'imprisoned',
#   'men',
#   'bond',
#   'number',
#   'years',
#   'finding',
#   'solace',
#   'eventual',
#   'redemption',
#   'acts',
#   'common',
#   'decency'],
#  ['twelve',
#   'strangers',
#   'wake',
#   'clearing',
#   'know',
#   'are',
#   'got',
#   'there',
#   'know',
#   'they',
#   've',
#   'chosen',
#   'specific',
#   'purpose',
#   'hunt'],
#  ['group',
#   'ambitious',
#   'law',
#   'students',
#   'brilliant',
#   'criminal',
#   'defense',
#   'professor',
#   'become',
#   'involved',
#   'twisted',
#   'murder',
#   'plot',
#   'promises',
#   'change',
#   'course',
#   'lives'],
#  ['young',
#   'nurse',
#   'mental',
#   'institution',
#   'becomes',
#   'jaded',
#   'bitter',
#   'downright',
#   'monster',
#   'patients'],
#  ['modern',
#   'update',
#   'finds',
#   'famous',
#   'sleuth',
#   'doctor',
#   'partner',
#   'solving',
#   'crime',
#   '21st',
#   'century',
#   'london'],
#  ['forensic',
#   'anthropologist',
#   'dr',
#   'temperance',
#   'bones',
#   'brennan',
#   'cocky',
#   'f',
#   'b',
#   'i',
#   'special',
#   'agent',
#   'seeley',
#   'booth',
#   'build',
#   'team',
#   'investigate',
#   'murders',
#   'quite',
#   'often',
#   'examine',
#   'rotten',
#   'flesh',
#   'mere',
#   'bones'],
#  ['jumanji',
#   'next',
#   'level',
#   'gang',
#   'back',
#   'game',
#   'changed',
#   'return',
#   'rescue',
#   'one',
#   'own',
#   'players',
#   'brave',
#   'parts',
#   'unknown',
#   'arid',
#   'deserts',
#   'snowy',
#   'mountains',
#   'escape',
#   'world',
#   's',
#   'dangerous',
#   'game'],
#  ['due',
#   'political',
#   'conspiracy',
#   'innocent',
#   'man',
#   'sent',
#   'death',
#   'row',
#   'hope',
#   'brother',
#   'makes',
#   'mission',
#   'deliberately',
#   'get',
#   'sent',
#   'prison',
#   'order',
#   'break',
#   'out',
#   'inside'],
#  ['animated',
#   'series',
#   'follows',
#   'exploits',
#   'super',
#   'scientist',
#   'not',
#   'so',
#   'bright',
#   'grandson'],
#  ['tv',
#   'adaptation',
#   'aldous',
#   'huxley',
#   's',
#   'book',
#   'set',
#   'dystopian',
#   'future'],
#  ['seasonal',
#   'anthology',
#   'series',
#   'police',
#   'investigations',
#   'unearth',
#   'personal',
#   'professional',
#   'secrets',
#   'involved',
#   'within',
#   'outside',
#   'law'],
#  ['struck',
#   'lightning',
#   'barry',
#   'allen',
#   'wakes',
#   'coma',
#   'discover',
#   'he',
#   's',
#   'given',
#   'power',
#   'super',
#   'speed',
#   'becoming',
#   'next',
#   'flash',
#   'fighting',
#   'crime',
#   'central',
#   'city'],
#  ['team',
#   'explorers',
#   'travel',
#   'wormhole',
#   'space',
#   'attempt',
#   'ensure',
#   'humanity',
#   's',
#   'survival'],
#  ['ophelia',
#   'falls',
#   'married',
#   'lecturer',
#   'michael',
#   'mysteriously',
#   'disappears',
#   'tracks',
#   'discovers',
#   'wife',
#   'died',
#   'fire'],
#  ['waking',
#   'morgue',
#   'orphaned',
#   'teen',
#   'discovers',
#   'possesses',
#   'superpowers',
#   'chosen',
#   'halo',
#   'bearer',
#   'secret',
#   'sect',
#   'demon',
#   'hunting',
#   'nuns'],
#  ['veteran',
#   'detective',
#   'chief',
#   'inspector',
#   'young',
#   'sergeant',
#   'investigate',
#   'murders',
#   'around',
#   'regional',
#   'community',
#   'midsomer',
#   'county'],
#  ['heartwarming',
#   'emotional',
#   'story',
#   'unique',
#   'set',
#   'triplets',
#   'struggles',
#   'wonderful',
#   'parents'],
#  ['scott',
#   'pilgrim',
#   'must',
#   'defeat',
#   'new',
#   'girlfriend',
#   's',
#   'seven',
#   'evil',
#   'exes',
#   'order',
#   'win',
#   'heart'],
#  ['drama',
#   'one',
#   'new',
#   'york',
#   's',
#   'prestigious',
#   'ad',
#   'agencies',
#   'beginning',
#   '1960s',
#   'focusing',
#   'one',
#   'firm',
#   's',
#   'mysterious',
#   'extremely',
#   'talented',
#   'ad',
#   'executives',
#   'donald',
#   'draper'],
#  ['april',
#   '6th',
#   '1917',
#   'regiment',
#   'assembles',
#   'wage',
#   'war',
#   'deep',
#   'enemy',
#   'territory',
#   'two',
#   'soldiers',
#   'assigned',
#   'race',
#   'time',
#   'deliver',
#   'message',
#   'stop',
#   '1',
#   '600',
#   'men',
#   'walking',
#   'straight',
#   'deadly',
#   'trap'],
#  ['parents',
#   'go',
#   'town',
#   'dennis',
#   'stays',
#   'mr',
#   'mrs',
#   'wilson',
#   'little',
#   'menace',
#   'driving',
#   'mr',
#   'wilson',
#   'crazy',
#   'dennis',
#   'trying',
#   'helpful',
#   'even',
#   'thief',
#   'who',
#   's',
#   'arrived',
#   'town'],
#  ['film',
#   'follows',
#   'small',
#   'town',
#   'cop',
#   'summoned',
#   'investigate',
#   'death',
#   'politician',
#   'gets',
#   'complicated',
#   'victim',
#   's',
#   'secretive',
#   'family',
#   'conflicted',
#   'heart'],
#  ['chronicle',
#   'lives',
#   'british',
#   'aristocratic',
#   'crawley',
#   'family',
#   'servants',
#   'early',
#   'twentieth',
#   'century'],
#  ['five',
#   'friends',
#   'big',
#   'egos',
#   'small',
#   'brains',
#   'proprietors',
#   'irish',
#   'pub',
#   'philadelphia'],
#  ['spoiled',
#   'billionaire',
#   'playboy',
#   'oliver',
#   'queen',
#   'missing',
#   'presumed',
#   'dead',
#   'yacht',
#   'lost',
#   'sea',
#   'returns',
#   'five',
#   'years',
#   'later',
#   'changed',
#   'man',
#   'determined',
#   'clean',
#   'city',
#   'hooded',
#   'vigilante',
#   'armed',
#   'bow'],
#  ['aging',
#   'patriarch',
#   'organized',
#   'crime',
#   'dynasty',
#   'transfers',
#   'control',
#   'clandestine',
#   'empire',
#   'reluctant',
#   'son'],
#  ['follows',
#   'us',
#   'american',
#   'football',
#   'coach',
#   'ted',
#   'lasso',
#   'heading',
#   'uk',
#   'manage',
#   'struggling',
#   'london',
#   'soccer',
#   'team',
#   'top',
#   'flight',
#   'english',
#   'football'],
#  ['viking', 'life', 'close', '8th', 'century'],
#  ['young',
#   'systems',
#   'engineer',
#   'blows',
#   'whistle',
#   'dangerous',
#   'technology',
#   'charlie',
#   's',
#   'angels',
#   'called',
#   'action',
#   'putting',
#   'lives',
#   'line',
#   'protect',
#   'us',
#   'all'],
#  ['sequel',
#   '2016',
#   'south',
#   'korean',
#   'zombie',
#   'film',
#   'train',
#   'busan',
#   '2016'],
#  ['couple',
#   'travels',
#   'sweden',
#   'visit',
#   'rural',
#   'hometown',
#   's',
#   'fabled',
#   'mid',
#   'summer',
#   'festival',
#   'begins',
#   'idyllic',
#   'retreat',
#   'quickly',
#   'devolves',
#   'increasingly',
#   'violent',
#   'bizarre',
#   'competition',
#   'hands',
#   'pagan',
#   'cult'],
#  ['american',
#   'car',
#   'designer',
#   'carroll',
#   'shelby',
#   'driver',
#   'ken',
#   'miles',
#   'battle',
#   'corporate',
#   'interference',
#   'laws',
#   'physics',
#   'build',
#   'revolutionary',
#   'race',
#   'car',
#   'ford',
#   'order',
#   'defeat',
#   'ferrari',
#   '24',
#   'hours',
#   'le',
#   'mans',
#   '1966'],
#  ['two',
#   'sisters',
#   'discover',
#   'disturbing',
#   'family',
#   'secrets',
#   'string',
#   'mysterious',
#   'deaths',
#   'occur',
#   'luxury',
#   'ship',
#   'traveling',
#   'spain',
#   'brazil',
#   '1940s'],
#  ['two',
#   'f',
#   'b',
#   'i',
#   'agents',
#   'fox',
#   'mulder',
#   'believer',
#   'dana',
#   'scully',
#   'skeptic',
#   'investigate',
#   'strange',
#   'unexplained',
#   'hidden',
#   'forces',
#   'work',
#   'impede',
#   'efforts'],
#  ['debbie',
#   'ocean',
#   'gathers',
#   'all',
#   'female',
#   'crew',
#   'attempt',
#   'impossible',
#   'heist',
#   'new',
#   'york',
#   'city',
#   's',
#   'yearly',
#   'met',
#   'gala'],
#  ['amy', 'thinks', 'dying', 'tomorrow', 'and', 'contagious'],
#  ['six',
#   'friends',
#   'hire',
#   'medium',
#   'hold',
#   'seance',
#   'via',
#   'zoom',
#   'lockdown',
#   'get',
#   'far',
#   'bargained',
#   'things',
#   'quickly',
#   'go',
#   'wrong',
#   'evil',
#   'spirit',
#   'starts',
#   'invading',
#   'see',
#   'full',
#   'summary'],
#  ['jo',
#   'march',
#   'reflects',
#   'back',
#   'forth',
#   'life',
#   'telling',
#   'beloved',
#   'story',
#   'march',
#   'sisters',
#   'four',
#   'young',
#   'women',
#   'determined',
#   'live',
#   'life',
#   'terms'],
#  ['continuing',
#   'misadventures',
#   'neurotic',
#   'new',
#   'york',
#   'city',
#   'stand',
#   'up',
#   'comedian',
#   'jerry',
#   'seinfeld',
#   'equally',
#   'neurotic',
#   'new',
#   'york',
#   'city',
#   'friends'],
#  ['satiric',
#   'adventures',
#   'working',
#   'class',
#   'family',
#   'misfit',
#   'city',
#   'springfield'],
#  ['set',
#   'late',
#   '1970s',
#   'two',
#   'fbi',
#   'agents',
#   'tasked',
#   'interviewing',
#   'serial',
#   'killers',
#   'solve',
#   'open',
#   'cases'],
#  ['full',
#   'misgivings',
#   'young',
#   'woman',
#   'travels',
#   'new',
#   'boyfriend',
#   'parents',
#   'secluded',
#   'farm',
#   'upon',
#   'arriving',
#   'comes',
#   'question',
#   'everything',
#   'thought',
#   'knew',
#   'him',
#   'herself',
#   'based',
#   'iain',
#   'reid',
#   's',
#   'acclaimed',
#   'novel'],
#  ['lives',
#   'loves',
#   'losses',
#   'doctors',
#   'nurses',
#   'chicago',
#   's',
#   'county',
#   'general',
#   'hospital'],
#  ['james',
#   'bond',
#   'left',
#   'active',
#   'service',
#   'peace',
#   'short',
#   'lived',
#   'felix',
#   'leiter',
#   'old',
#   'friend',
#   'cia',
#   'turns',
#   'asking',
#   'help',
#   'leading',
#   'bond',
#   'onto',
#   'trail',
#   'mysterious',
#   'villain',
#   'armed',
#   'dangerous',
#   'new',
#   'technology'],
#  ['bella',
#   'swan',
#   'moves',
#   'forks',
#   'encounters',
#   'edward',
#   'cullen',
#   'gorgeous',
#   'boy',
#   'secret'],
#  ['orphaned',
#   'boy',
#   'enrolls',
#   'school',
#   'wizardry',
#   'learns',
#   'truth',
#   'himself',
#   'family',
#   'terrible',
#   'evil',
#   'haunts',
#   'magical',
#   'world'],
#  ['look',
#   'daily',
#   'or',
#   'rather',
#   'nightly',
#   'lives',
#   'three',
#   'vampires',
#   'who',
#   've',
#   'lived',
#   'together',
#   '100',
#   'years',
#   'staten',
#   'island'],
#  ['support',
#   'crew',
#   'serving',
#   'one',
#   'starfleet',
#   's',
#   'least',
#   'important',
#   'ships',
#   'u',
#   's',
#   's',
#   'cerritos',
#   'keep',
#   'duties',
#   'often',
#   'ship',
#   'rocked',
#   'multitude',
#   'sci',
#   'fi',
#   'anomalies'],
#  ['seven',
#   'years',
#   'world',
#   'become',
#   'frozen',
#   'wasteland',
#   'remnants',
#   'humanity',
#   'inhabit',
#   'perpetually',
#   'moving',
#   'train',
#   'circles',
#   'globe',
#   'class',
#   'warfare',
#   'social',
#   'injustice',
#   'politics',
#   'survival',
#   'play',
#   'out'],
#  ['joining',
#   'forces',
#   'veteran',
#   'bounty',
#   'hunter',
#   'sixteen',
#   'year',
#   'old',
#   'fraternal',
#   'twin',
#   'sisters',
#   'sterling',
#   'blair',
#   'dive',
#   'world',
#   'bail',
#   'skipping',
#   'baddies',
#   'still',
#   'navigating',
#   'high',
#   'stakes',
#   'teenage',
#   'life'],
#  ['novice',
#   'sleuth',
#   'hired',
#   'police',
#   'cons',
#   'thinking',
#   'psychic',
#   'powers',
#   'help',
#   'solve',
#   'crimes',
#   'assistance',
#   'reluctant',
#   'best',
#   'friend',
#   'duo',
#   'take',
#   'series',
#   'complicated',
#   'cases'],
#  ['plot', 'unknown'],
#  ['u',
#   's',
#   'attorney',
#   'chuck',
#   'rhoades',
#   'goes',
#   'hedge',
#   'fund',
#   'king',
#   'bobby',
#   'axe',
#   'axelrod',
#   'battle',
#   'two',
#   'powerful',
#   'new',
#   'york',
#   'figures'],
#  ['hedonistic',
#   'jingle',
#   'writer',
#   's',
#   'free',
#   'wheeling',
#   'life',
#   'comes',
#   'abrupt',
#   'halt',
#   'brother',
#   '10',
#   'year',
#   'old',
#   'nephew',
#   'move',
#   'beach',
#   'front',
#   'house'],
#  ['based',
#   'true',
#   'story',
#   'jordan',
#   'belfort',
#   'rise',
#   'wealthy',
#   'stock',
#   'broker',
#   'living',
#   'high',
#   'life',
#   'fall',
#   'involving',
#   'crime',
#   'corruption',
#   'federal',
#   'government'],
#  ['inside',
#   'look',
#   'lives',
#   'people',
#   'help',
#   'america',
#   'wake',
#   'morning',
#   'exploring',
#   'unique',
#   'challenges',
#   'faced',
#   'men',
#   'women',
#   'carry',
#   'daily',
#   'televised',
#   'ritual'],
#  ['former',
#   'dea',
#   'agent',
#   'moves',
#   'family',
#   'quiet',
#   'town',
#   'soon',
#   'tangles',
#   'local',
#   'meth',
#   'druglord'],
#  ['cecilia',
#   's',
#   'abusive',
#   'ex',
#   'takes',
#   'life',
#   'leaves',
#   'fortune',
#   'suspects',
#   'death',
#   'hoax',
#   'series',
#   'coincidences',
#   'turn',
#   'lethal',
#   'cecilia',
#   'works',
#   'prove',
#   'hunted',
#   'someone',
#   'nobody',
#   'see'],
#  ['story', 'battle', 'midway', 'told', 'leaders', 'sailors', 'fought', 'it'],
#  ['follows',
#   'teenager',
#   'clay',
#   'jensen',
#   'quest',
#   'uncover',
#   'story',
#   'behind',
#   'classmate',
#   'crush',
#   'hannah',
#   'decision',
#   'end',
#   'life'],
#  ['equal',
#   'parts',
#   'high',
#   'concept',
#   'thriller',
#   'coming',
#   'of',
#   'age',
#   'drama',
#   'hanna',
#   'follows',
#   'journey',
#   'extraordinary',
#   'young',
#   'girl',
#   'raised',
#   'forest',
#   'evades',
#   'relentless',
#   'pursuit',
#   'off',
#   'book',
#   'cia',
#   'agent',
#   'tries',
#   'unearth',
#   'truth',
#   'behind',
#   'is'],
#  ['inside', 'lives', 'staffers', 'west', 'wing', 'white', 'house'],
#  ['young',
#   'woman',
#   'falls',
#   'guy',
#   'dark',
#   'secret',
#   'two',
#   'embark',
#   'rocky',
#   'relationship',
#   'based',
#   'novel',
#   'anna',
#   'todd'],
#  ['menace',
#   'known',
#   'joker',
#   'wreaks',
#   'havoc',
#   'chaos',
#   'people',
#   'gotham',
#   'batman',
#   'must',
#   'accept',
#   'one',
#   'greatest',
#   'psychological',
#   'physical',
#   'tests',
#   'ability',
#   'fight',
#   'injustice'],
#  ['city',
#   'state',
#   'panic',
#   'misinformation',
#   'traveling',
#   'speed',
#   'social',
#   'media',
#   'mike',
#   's',
#   'life',
#   'family',
#   'hang',
#   'balance',
#   'becomes',
#   'fugitive'],
#  ['avatar',
#   'korra',
#   'fights',
#   'keep',
#   'republic',
#   'city',
#   'safe',
#   'evil',
#   'forces',
#   'physical',
#   'spiritual',
#   'worlds'],
#  ['teresa',
#   'flees',
#   'mexico',
#   'drug',
#   'runner',
#   'boyfriend',
#   'murdered',
#   'settling',
#   'dallas',
#   'looks',
#   'become',
#   'country',
#   's',
#   'reigning',
#   'drug',
#   'smuggler',
#   'avenge',
#   'lover',
#   's',
#   'murder'],
#  ['post',
#   'apocalyptic',
#   'wasteland',
#   'woman',
#   'rebels',
#   'tyrannical',
#   'ruler',
#   'search',
#   'homeland',
#   'aid',
#   'group',
#   'female',
#   'prisoners',
#   'psychotic',
#   'worshiper',
#   'drifter',
#   'named',
#   'max'],
#  ['last',
#   'ditch',
#   'effort',
#   'win',
#   'girl',
#   'dreams',
#   'nerdy',
#   'high',
#   'school',
#   'senior',
#   'best',
#   'friends',
#   'embark',
#   'road',
#   'trip',
#   'see',
#   'favorite',
#   'band',
#   'biggest',
#   'music',
#   'festival',
#   'year'],
#  ['follows',
#   'district',
#   '21',
#   'chicago',
#   'police',
#   'department',
#   'made',
#   'two',
#   'distinctly',
#   'different',
#   'groups',
#   'uniformed',
#   'cops',
#   'intelligence',
#   'unit'],
#  ['series',
#   'events',
#   'lives',
#   'security',
#   'operative',
#   'assassin',
#   'become',
#   'inextricably',
#   'linked'],
#  ['elliot',
#   'brilliant',
#   'highly',
#   'unstable',
#   'young',
#   'cyber',
#   'security',
#   'engineer',
#   'vigilante',
#   'hacker',
#   'becomes',
#   'key',
#   'figure',
#   'complex',
#   'game',
#   'global',
#   'dominance',
#   'shadowy',
#   'allies',
#   'try',
#   'take',
#   'corrupt',
#   'corporation',
#   'works',
#   'for'],
#  ['students',
#   'united',
#   'states',
#   'navy',
#   's',
#   'elite',
#   'fighter',
#   'weapons',
#   'school',
#   'compete',
#   'best',
#   'class',
#   'one',
#   'daring',
#   'young',
#   'pilot',
#   'learns',
#   'things',
#   'civilian',
#   'instructor',
#   'taught',
#   'classroom'],
#  ['legend', 'confrontation', 'seven', 'deadly', 'sins', 'holy', 'knights'],
#  ['ray', 'garrison', 'slain', 'soldier', 're', 'animated', 'superpowers'],
#  ['visual', 'album', 'beyonc', 'inspired', 'the', 'lion', 'king'],
#  ['follows', 'lives', 'strip', 'club', 'dancers', 'working', 'dirty', 'delta'],
#  ['police',
#   'detective',
#   'asteroid',
#   'belt',
#   'first',
#   'officer',
#   'interplanetary',
#   'ice',
#   'freighter',
#   'earth',
#   'bound',
#   'united',
#   'nations',
#   'executive',
#   'slowly',
#   'discover',
#   'vast',
#   'conspiracy',
#   'threatens',
#   'earth',
#   's',
#   'rebellious',
#   'colony',
#   'asteroid',
#   'belt'],
#  ['teenage',
#   'boy',
#   'sex',
#   'therapist',
#   'mother',
#   'teams',
#   'high',
#   'school',
#   'classmate',
#   'set',
#   'underground',
#   'sex',
#   'therapy',
#   'clinic',
#   'school'],
#  ['follows',
#   'marianne',
#   'connell',
#   'different',
#   'backgrounds',
#   'small',
#   'town',
#   'ireland',
#   'weave',
#   'other',
#   's',
#   'romantic',
#   'lives'],
#  ['story', 'firefighters', 'chicago', 'personal', 'professional', 'level'],
#  ['declared',
#   'dead',
#   'absentia',
#   'fbi',
#   'agent',
#   'must',
#   'reclaim',
#   'family',
#   'identity',
#   'innocence',
#   'finds',
#   'prime',
#   'suspect',
#   'string',
#   'murders'],
#  ['debts',
#   'mounting',
#   'angry',
#   'collectors',
#   'closing',
#   'in',
#   'fast',
#   'talking',
#   'new',
#   'york',
#   'city',
#   'jeweler',
#   'risks',
#   'everything',
#   'hope',
#   'staying',
#   'afloat',
#   'alive'],
#  ['married',
#   'alma',
#   'spends',
#   'fateful',
#   'weekend',
#   'away',
#   'home',
#   'ignites',
#   'passion',
#   'ends',
#   'tragedy',
#   'leads',
#   'question',
#   'truth',
#   'close',
#   'her'],
#  ['scott',
#   'case',
#   'arrested',
#   'development',
#   'since',
#   'firefighter',
#   'dad',
#   'died',
#   'spends',
#   'days',
#   'smoking',
#   'weed',
#   'dreaming',
#   'tattoo',
#   'artist',
#   'events',
#   'force',
#   'grapple',
#   'grief',
#   'take',
#   'first',
#   'steps',
#   'forward',
#   'life'],
#  ['famous',
#   'psychic',
#   'outs',
#   'fake',
#   'starts',
#   'working',
#   'consultant',
#   'california',
#   'bureau',
#   'investigation',
#   'find',
#   'red',
#   'john',
#   'madman',
#   'killed',
#   'wife',
#   'daughter'],
#  ['navigating',
#   'troubled',
#   'waters',
#   'romance',
#   'school',
#   'family',
#   'archie',
#   'gang',
#   'become',
#   'entangled',
#   'dark',
#   'riverdale',
#   'mysteries'],
#  ['thirty',
#   'years',
#   'service',
#   'one',
#   'navy',
#   's',
#   'top',
#   'aviators',
#   'pete',
#   'mitchell',
#   'belongs',
#   'pushing',
#   'envelope',
#   'courageous',
#   'test',
#   'pilot',
#   'dodging',
#   'advancement',
#   'rank',
#   'would',
#   'ground',
#   'him'],
#  ['surviving',
#   'members',
#   'resistance',
#   'face',
#   'first',
#   'order',
#   'again',
#   'legendary',
#   'conflict',
#   'jedi',
#   'sith',
#   'reaches',
#   'peak',
#   'bringing',
#   'skywalker',
#   'saga',
#   'end'],
#  ['splitting',
#   'joker',
#   'harley',
#   'quinn',
#   'joins',
#   'superheroes',
#   'black',
#   'canary',
#   'huntress',
#   'renee',
#   'montoya',
#   'save',
#   'young',
#   'girl',
#   'evil',
#   'crime',
#   'lord'],
#  ['follows',
#   'crime',
#   'usually',
#   'murder',
#   'usually',
#   'adapted',
#   'current',
#   'headlines',
#   'two',
#   'separate',
#   'vantage',
#   'points',
#   'police',
#   'investigation',
#   'prosecution',
#   'court'],
#  ['believes',
#   'wife',
#   'rosalind',
#   'innocent',
#   'son',
#   's',
#   'suspected',
#   'murder',
#   'discover',
#   'devastating',
#   'truth',
#   'behind',
#   'past',
#   'links',
#   'another',
#   'unsolved',
#   'crime'],
#  ['convicted',
#   'decade',
#   'old',
#   'crime',
#   'transporting',
#   'drug',
#   'money',
#   'ex',
#   'girlfriend',
#   'normally',
#   'law',
#   'abiding',
#   'piper',
#   'chapman',
#   'sentenced',
#   'year',
#   'half',
#   'behind',
#   'bars',
#   'face',
#   'reality',
#   'life',
#   'changing',
#   'prison',
#   'really',
#   'be'],
#  ['kyle',
#   'swin',
#   'live',
#   'orders',
#   'arkansas',
#   'based',
#   'drug',
#   'kingpin',
#   'named',
#   'frog',
#   'they',
#   've',
#   'never',
#   'met',
#   'deal',
#   'goes',
#   'horribly',
#   'wrong',
#   'consequences',
#   'deadly'],
#  ['tyler',
#   'rake',
#   'fearless',
#   'black',
#   'market',
#   'mercenary',
#   'embarks',
#   'deadly',
#   'extraction',
#   'career',
#   'he',
#   's',
#   'enlisted',
#   'rescue',
#   'kidnapped',
#   'son',
#   'imprisoned',
#   'international',
#   'crime',
#   'lord'],
#  ['two',
#   'lighthouse',
#   'keepers',
#   'try',
#   'maintain',
#   'sanity',
#   'whilst',
#   'living',
#   'remote',
#   'mysterious',
#   'new',
#   'england',
#   'island',
#   '1890s'],
#  ['margaret',
#   'alexandra',
#   'daddario',
#   'finds',
#   'glittering',
#   'labyrinth',
#   'tokyo',
#   'night',
#   'respected',
#   'english',
#   'teacher',
#   'japanese',
#   'flight',
#   'attendant',
#   'academy',
#   'day',
#   'little',
#   'life',
#   'see',
#   'full',
#   'summary'],
#  ['housewife', '1958', 'decides', 'become', 'stand', 'up', 'comic'],
#  ['self',
#   'destructing',
#   'world',
#   'vengeful',
#   'australian',
#   'policeman',
#   'sets',
#   'stop',
#   'violent',
#   'motorcycle',
#   'gang'],
#  ['low',
#   'level',
#   'cabinet',
#   'member',
#   'becomes',
#   'president',
#   'united',
#   'states',
#   'catastrophic',
#   'attack',
#   'kills',
#   'everyone',
#   'line',
#   'succession'],
#  ['hometown',
#   'destroyed',
#   'mother',
#   'killed',
#   'young',
#   'eren',
#   'yeager',
#   'vows',
#   'cleanse',
#   'earth',
#   'giant',
#   'humanoid',
#   'titans',
#   'brought',
#   'humanity',
#   'brink',
#   'extinction'],
#  ['frontiersman',
#   'fur',
#   'trading',
#   'expedition',
#   '1820s',
#   'fights',
#   'survival',
#   'mauled',
#   'bear',
#   'left',
#   'dead',
#   'members',
#   'hunting',
#   'team'],
#  ['sparks',
#   'fly',
#   'spirited',
#   'elizabeth',
#   'bennet',
#   'meets',
#   'single',
#   'rich',
#   'proud',
#   'mr',
#   'darcy',
#   'mr',
#   'darcy',
#   'reluctantly',
#   'finds',
#   'falling',
#   'love',
#   'woman',
#   'beneath',
#   'class',
#   'overcome',
#   'pride',
#   'prejudice'],
#  ['master',
#   'dies',
#   'peasant',
#   'squire',
#   'fueled',
#   'desire',
#   'food',
#   'glory',
#   'creates',
#   'new',
#   'identity',
#   'knight'],
#  ['new',
#   'yorker',
#   'new',
#   'doctor',
#   'zoe',
#   'hart',
#   'accepts',
#   'offer',
#   'stranger',
#   'dr',
#   'harley',
#   'wilkes',
#   'work',
#   'medical',
#   'practice',
#   'bluebell',
#   'alabama',
#   'arrives',
#   'find',
#   'died',
#   'left',
#   'half',
#   'practice',
#   'will'],
#  ['unreal',
#   'world',
#   'sacred',
#   'heart',
#   'hospital',
#   'intern',
#   'john',
#   'j',
#   'd',
#   'dorian',
#   'learns',
#   'ways',
#   'medicine',
#   'friendship',
#   'life'],
#  ['based',
#   'novel',
#   'six',
#   'days',
#   'condor',
#   'james',
#   'grady',
#   'screenplay',
#   'three',
#   'days',
#   'condor',
#   'lorenzo',
#   'semple',
#   'jr',
#   'david',
#   'rayfiel',
#   'condor',
#   'follows',
#   'cia',
#   'analyst',
#   'joe',
#   'turner',
#   'see',
#   'full',
#   'summary'],
#  ['family',
#   'heads',
#   'isolated',
#   'hotel',
#   'winter',
#   'sinister',
#   'presence',
#   'influences',
#   'father',
#   'violence',
#   'psychic',
#   'son',
#   'sees',
#   'horrific',
#   'forebodings',
#   'past',
#   'future'],
#  ['series',
#   'focuses',
#   'single',
#   'harley',
#   'quinn',
#   'sets',
#   'make',
#   'gotham',
#   'city'],
#  ['computer',
#   'hacker',
#   'learns',
#   'mysterious',
#   'rebels',
#   'true',
#   'nature',
#   'reality',
#   'role',
#   'war',
#   'controllers'],
#  ['series',
#   'powerful',
#   'friendship',
#   'blossoms',
#   'tightly',
#   'wound',
#   'widow',
#   'free',
#   'spirit',
#   'shocking',
#   'secret'],
#  ['tv',
#   'adaptation',
#   'anais',
#   'nin',
#   's',
#   'infamous',
#   'collection',
#   'erotic',
#   'short',
#   'stories'],
#  ['vicinity',
#   'liberated',
#   'planet',
#   'bajor',
#   'federation',
#   'space',
#   'station',
#   'deep',
#   'space',
#   'nine',
#   'guards',
#   'opening',
#   'stable',
#   'wormhole',
#   'far',
#   'side',
#   'galaxy'],
#  ['l',
#   'a',
#   'p',
#   'd',
#   'homicide',
#   'detective',
#   'works',
#   'solve',
#   'murder',
#   'thirteen',
#   'year',
#   'old',
#   'boy',
#   'standing',
#   'trial',
#   'federal',
#   'court',
#   'murder',
#   'serial',
#   'killer'],
#  ['set',
#   'near',
#   'future',
#   'technology',
#   'controls',
#   'nearly',
#   'aspects',
#   'life',
#   'world',
#   'grey',
#   'self',
#   'labeled',
#   'technophobe',
#   'turned',
#   'upside',
#   'down',
#   'hope',
#   'revenge',
#   'experimental',
#   'computer',
#   'chip',
#   'implant'],
#  ['jack',
#   'bauer',
#   'races',
#   'clock',
#   'subvert',
#   'terrorist',
#   'plots',
#   'save',
#   'nation',
#   'ultimate',
#   'disaster'],
#  ['up',
#   'and',
#   'coming',
#   'cia',
#   'analyst',
#   'jack',
#   'ryan',
#   'thrust',
#   'dangerous',
#   'field',
#   'assignment',
#   'uncovers',
#   'pattern',
#   'terrorist',
#   'communication',
#   'launches',
#   'center',
#   'dangerous',
#   'gambit'],
#  ['lives',
#   'two',
#   'mob',
#   'hitmen',
#   'boxer',
#   'gangster',
#   'wife',
#   'pair',
#   'diner',
#   'bandits',
#   'intertwine',
#   'four',
#   'tales',
#   'violence',
#   'redemption'],
#  ['celebrates',
#   'birth',
#   'show',
#   'business',
#   'tells',
#   'visionary',
#   'rose',
#   'nothing',
#   'create',
#   'spectacle',
#   'became',
#   'worldwide',
#   'sensation'],
#  ['royal',
#   'woman',
#   'living',
#   'rural',
#   'russia',
#   '18th',
#   'century',
#   'forced',
#   'choose',
#   'personal',
#   'happiness',
#   'future',
#   'russia',
#   'marries',
#   'emperor'],
#  ['naima',
#   '16',
#   'lives',
#   'cannes',
#   'given',
#   'summer',
#   'choose',
#   'wants',
#   'life',
#   'cousin',
#   'sofia',
#   'alluring',
#   'lifestyle',
#   'arrives',
#   'spend',
#   'holidays',
#   'her'],
#  ['cases',
#   'master',
#   'criminal',
#   'defense',
#   'attorney',
#   'handling',
#   'difficult',
#   'cases',
#   'aid',
#   'innocent'],
#  ['duke',
#   's',
#   'son',
#   'leads',
#   'desert',
#   'warriors',
#   'galactic',
#   'emperor',
#   'father',
#   's',
#   'evil',
#   'nemesis',
#   'assassinate',
#   'father',
#   'free',
#   'desert',
#   'world',
#   'emperor',
#   's',
#   'rule'],
#  ['shaun',
#   'murphy',
#   'young',
#   'surgeon',
#   'autism',
#   'savant',
#   'syndrome',
#   'recruited',
#   'surgical',
#   'unit',
#   'prestigious',
# ...
#   'sure',
#   'psychopath',
#   'alyssa',
#   'also',
#   '17',
#   'cool',
#   'moody',
#   'new',
#   'girl',
#   'school',
#   'pair',
#   'make',
#   'connection',
#   'persuades',
#   'embark',
#   'road',
#   'trip',
#   'search',
#   'real',
#   'father'],
#  ['emotionally',
#   'troubled',
#   'young',
#   'woman',
#   'sets',
#   'exact',
#   'revenge',
#   'people',
#   'wronged',
#   'father'],
#  ['lives', 'tragedies', 'braverman', 'family', 'tree'],
#  ['group',
#   'friends',
#   'meet',
#   'regularly',
#   'game',
#   'nights',
#   'find',
#   'entangled',
#   'real',
#   'life',
#   'mystery',
#   'shady',
#   'brother',
#   'one',
#   'seemingly',
#   'kidnapped',
#   'dangerous',
#   'gangsters'],
#  ['cunningham',
#   'family',
#   'live',
#   '1950s',
#   'help',
#   'guidance',
#   'lovable',
#   'almost',
#   'superhuman',
#   'greaser',
#   'fonzie'],
#  ['fan',
#   'music',
#   'pop',
#   'culture',
#   'top',
#   'five',
#   'lists',
#   'runs',
#   'local',
#   'record',
#   'store',
#   'hometown',
#   'adaptation',
#   'nick',
#   'hornby',
#   's',
#   'novel',
#   'high',
#   'fidelity'],
#  ['five',
#   'years',
#   'events',
#   'mamma',
#   'mia',
#   '2008',
#   'sophie',
#   'prepares',
#   'grand',
#   'reopening',
#   'hotel',
#   'bella',
#   'donna',
#   'learns',
#   'mother',
#   's',
#   'past'],
#  ['woman',
#   'rescued',
#   'doomsday',
#   'cult',
#   'starts',
#   'life',
#   'new',
#   'york',
#   'city'],
#  ['harry',
#   'daniel',
#   'radcliffe',
#   'ron',
#   'rupert',
#   'grint',
#   'hermione',
#   'emma',
#   'watson',
#   'race',
#   'time',
#   'evil',
#   'destroy',
#   'horcruxes',
#   'uncover',
#   'existence',
#   'three',
#   'powerful',
#   'objects',
#   'wizarding',
#   'world',
#   'deathly',
#   'hallows'],
#  ['new',
#   'jersey',
#   'ramy',
#   'son',
#   'egyptian',
#   'migrants',
#   'begins',
#   'spiritual',
#   'journey',
#   'divided',
#   'muslim',
#   'community',
#   'god',
#   'friends',
#   'see',
#   'endless',
#   'possibilities'],
#  ['crimes',
#   'eyes',
#   'team',
#   'forensic',
#   'pathologists',
#   'forensic',
#   'scientists'],
#  ['mortal',
#   'hero',
#   'bek',
#   'teams',
#   'god',
#   'horus',
#   'alliance',
#   'set',
#   'merciless',
#   'god',
#   'darkness',
#   'usurped',
#   'egypt',
#   's',
#   'throne',
#   'plunging',
#   'peaceful',
#   'prosperous',
#   'empire',
#   'chaos',
#   'conflict'],
#  ['follows',
#   'four',
#   'teenage',
#   'girls',
#   'private',
#   'elite',
#   'school',
#   'form',
#   'secret',
#   'society',
#   'expose',
#   'bullies'],
#  ['trip',
#   'paris',
#   'fiance',
#   's',
#   'family',
#   'nostalgic',
#   'screenwriter',
#   'finds',
#   'mysteriously',
#   'going',
#   'back',
#   '1920s',
#   'every',
#   'day',
#   'midnight'],
#  ['story',
#   'chaukdi',
#   'gang',
#   'two',
#   'men',
#   'helped',
#   'build',
#   'gang',
#   'played',
#   'vidyut',
#   'jammwal',
#   'amit',
#   'sadh',
#   'gang',
#   'four',
#   'includes',
#   'vijay',
#   'varma',
#   'nabbed',
#   'police',
#   'serve',
#   'see',
#   'full',
#   'summary'],
#  ['pose',
#   'set',
#   'world',
#   '1987',
#   'looks',
#   'juxtaposition',
#   'several',
#   'segments',
#   'life',
#   'society',
#   'new',
#   'york',
#   'rise',
#   'luxury',
#   'universe',
#   'downtown',
#   'social',
#   'literary',
#   'scene',
#   'ball',
#   'culture',
#   'world'],
#  ['extraordinary',
#   'tale',
#   'harriet',
#   'tubman',
#   's',
#   'escape',
#   'slavery',
#   'transformation',
#   'one',
#   'america',
#   's',
#   'greatest',
#   'heroes',
#   'whose',
#   'courage',
#   'ingenuity',
#   'tenacity',
#   'freed',
#   'hundreds',
#   'slaves',
#   'changed',
#   'course',
#   'history'],
#  ['sled', 'dog', 'struggles', 'survival', 'wilds', 'yukon'],
#  ['world',
#   'war',
#   'ii',
#   'american',
#   'army',
#   'medic',
#   'desmond',
#   't',
#   'doss',
#   'served',
#   'battle',
#   'okinawa',
#   'refuses',
#   'kill',
#   'people',
#   'becomes',
#   'first',
#   'man',
#   'american',
#   'history',
#   'receive',
#   'medal',
#   'honor',
#   'without',
#   'firing',
#   'shot'],
#  ['young',
#   'angus',
#   'mac',
#   'macgyver',
#   'works',
#   'clandestine',
#   'organization',
#   'within',
#   'u',
#   's',
#   'government',
#   'relying',
#   'unconventional',
#   'problem',
#   'solving',
#   'skills',
#   'save',
#   'lives'],
#  ['earth',
#   'invaded',
#   'alien',
#   'tripod',
#   'fighting',
#   'machines',
#   'one',
#   'family',
#   'fights',
#   'survival',
#   'sci',
#   'fi',
#   'action',
#   'film'],
#  ['story',
#   'michael',
#   'oher',
#   'homeless',
#   'traumatized',
#   'boy',
#   'became',
#   'all',
#   'american',
#   'football',
#   'player',
#   'first',
#   'round',
#   'nfl',
#   'draft',
#   'pick',
#   'help',
#   'caring',
#   'woman',
#   'family'],
#  ['jerry',
#   'lundegaard',
#   's',
#   'inept',
#   'crime',
#   'falls',
#   'apart',
#   'due',
#   'henchmen',
#   's',
#   'bungling',
#   'persistent',
#   'police',
#   'work',
#   'quite',
#   'pregnant',
#   'marge',
#   'gunderson'],
#  ['naruto',
#   'uzumaki',
#   'loud',
#   'hyperactive',
#   'adolescent',
#   'ninja',
#   'constantly',
#   'searches',
#   'approval',
#   'recognition',
#   'well',
#   'become',
#   'hokage',
#   'acknowledged',
#   'leader',
#   'strongest',
#   'ninja',
#   'village'],
#  ['seemingly',
#   'confident',
#   'comedy',
#   'writer',
#   'wife',
#   'mom',
#   'comically',
#   'exposes',
#   'inner',
#   'immaturity',
#   'neuroses',
#   'unexpected',
#   'life',
#   'situations'],
#  ['skilled',
#   'london',
#   'police',
#   'officer',
#   'transferred',
#   'small',
#   'town',
#   'dark',
#   'secret'],
#  ['jack',
#   'sparrow',
#   'barbossa',
#   'embark',
#   'quest',
#   'find',
#   'elusive',
#   'fountain',
#   'youth',
#   'discover',
#   'blackbeard',
#   'daughter',
#   'too'],
#  ['kidnapped',
#   'imprisoned',
#   'fifteen',
#   'years',
#   'oh',
#   'dae',
#   'su',
#   'released',
#   'find',
#   'must',
#   'find',
#   'captor',
#   'five',
#   'days'],
#  ['mysterious',
#   'woman',
#   'perched',
#   'harsh',
#   'legacy',
#   'world',
#   'war',
#   'ii',
#   'hope',
#   'new',
#   'life',
#   'australia'],
#  ['plot', 'unknown', 'feature', 'film', 'based', 'popular', 'video', 'game'],
#  ['adolescent',
#   'two',
#   'siblings',
#   'tests',
#   'various',
#   'theories',
#   'life',
#   'endures',
#   'trials',
#   'growing',
#   'alongside',
#   'good',
#   'friend'],
#  ['elderly',
#   'spinster',
#   'living',
#   'village',
#   'st',
#   'mary',
#   'mead',
#   'helps',
#   'friends',
#   'relatives',
#   'solve',
#   'mysterious',
#   'murders'],
#  ['detroit',
#   'lonely',
#   'pop',
#   'culture',
#   'geek',
#   'marries',
#   'call',
#   'girl',
#   'steals',
#   'cocaine',
#   'pimp',
#   'tries',
#   'sell',
#   'hollywood',
#   'meanwhile',
#   'owners',
#   'cocaine',
#   'mob',
#   'track',
#   'attempt',
#   'reclaim',
#   'it'],
#  ['procedural',
#   'drama',
#   'inner',
#   'workings',
#   'new',
#   'york',
#   'office',
#   'fbi',
#   'bringing',
#   'bear',
#   'bureau',
#   's',
#   'skills',
#   'intellect',
#   'mind',
#   'blowing',
#   'technology',
#   'keep',
#   'new',
#   'york',
#   'country',
#   'safe'],
#  ['middle',
#   'aged',
#   'husband',
#   's',
#   'life',
#   'changes',
#   'dramatically',
#   'wife',
#   'asks',
#   'divorce',
#   'seeks',
#   'rediscover',
#   'manhood',
#   'help',
#   'newfound',
#   'friend',
#   'jacob',
#   'learning',
#   'pick',
#   'girls',
#   'bars'],
#  ['war',
#   'thriller',
#   'based',
#   'theme',
#   'indian',
#   'army',
#   'uri',
#   'surgical',
#   'strike'],
#  ['linguist',
#   'works',
#   'military',
#   'communicate',
#   'alien',
#   'lifeforms',
#   'twelve',
#   'mysterious',
#   'spacecraft',
#   'appear',
#   'around',
#   'world'],
#  ['akeem',
#   'learns',
#   'long',
#   'lost',
#   'son',
#   'united',
#   'states',
#   'must',
#   'return',
#   'america',
#   'meet',
#   'unlikely',
#   'heir',
#   'throne',
#   'zamunda',
#   'sequel',
#   '1988',
#   'comedy',
#   'coming',
#   'america'],
#  ['inspector',
#   'robert',
#   'lewis',
#   'sergeant',
#   'james',
#   'hathaway',
#   'solve',
#   'tough',
#   'cases',
#   'learned',
#   'inhabitants',
#   'oxford',
#   'throw',
#   'them'],
#  ['young',
#   'boy',
#   'stumbles',
#   'onto',
#   'witch',
#   'convention',
#   'must',
#   'stop',
#   'them',
#   'even',
#   'turned',
#   'mouse'],
#  ['viago',
#   'deacon',
#   'vladislav',
#   'vampires',
#   'finding',
#   'modern',
#   'life',
#   'struggling',
#   'mundane',
#   'like',
#   'paying',
#   'rent',
#   'keeping',
#   'chore',
#   'wheel',
#   'trying',
#   'get',
#   'nightclubs',
#   'overcoming',
#   'flatmate',
#   'conflicts'],
#  ['gay',
#   'lawyer',
#   'straight',
#   'interior',
#   'designer',
#   'grace',
#   'share',
#   'new',
#   'york',
#   'city',
#   'apartment',
#   'best',
#   'friends',
#   'gleeful',
#   'proud',
#   'gay',
#   'jack',
#   'charismatic',
#   'filthy',
#   'rich',
#   'amoral',
#   'socialite',
#   'karen'],
#  ['anthology',
#   'series',
#   'centered',
#   'around',
#   'mysterious',
#   'geist',
#   'group',
#   'unconventional',
#   'wellness',
#   'company',
#   'equally',
#   'unorthodox',
#   'program',
#   'homecoming',
#   'initiative'],
#  ['1970s',
#   'los',
#   'angeles',
#   'mismatched',
#   'pair',
#   'private',
#   'eyes',
#   'investigate',
#   'missing',
#   'girl',
#   'mysterious',
#   'death',
#   'porn',
#   'star'],
#  ['four',
#   'women',
#   'set',
#   'undercover',
#   'detective',
#   'agency',
#   'expose',
#   'philandering',
#   'husbands'],
#  ['robbed',
#   'birthright',
#   'arthur',
#   'comes',
#   'hard',
#   'way',
#   'back',
#   'alleys',
#   'city',
#   'pulls',
#   'sword',
#   'stone',
#   'forced',
#   'acknowledge',
#   'true',
#   'legacy',
#   'whether',
#   'likes',
#   'not'],
#  ['tough',
#   'cop',
#   'must',
#   'pose',
#   'kindergarten',
#   'teacher',
#   'order',
#   'locate',
#   'dangerous',
#   'criminal',
#   's',
#   'ex',
#   'wife',
#   'may',
#   'hold',
#   'key',
#   'putting',
#   'behind',
#   'bars'],
#  ['boy',
#   'new',
#   'york',
#   'taken',
#   'wealthy',
#   'upper',
#   'east',
#   'side',
#   'family',
#   'mother',
#   'killed',
#   'bombing',
#   'metropolitan',
#   'museum',
#   'art'],
#  ['newly',
#   'crowned',
#   'queen',
#   'elsa',
#   'accidentally',
#   'uses',
#   'power',
#   'turn',
#   'things',
#   'ice',
#   'curse',
#   'home',
#   'infinite',
#   'winter',
#   'sister',
#   'anna',
#   'teams',
#   'mountain',
#   'man',
#   'playful',
#   'reindeer',
#   'snowman',
#   'change',
#   'weather',
#   'condition'],
#  ['research',
#   'team',
#   'antarctica',
#   'hunted',
#   'shape',
#   'shifting',
#   'alien',
#   'assumes',
#   'appearance',
#   'victims'],
#  ['f',
#   'b',
#   'i',
#   'agent',
#   'goes',
#   'undercover',
#   'catch',
#   'gang',
#   'surfers',
#   'may',
#   'bank',
#   'robbers'],
#  ['blind',
#   'man',
#   'moves',
#   'apartment',
#   'wishes',
#   'overprotective',
#   'mother',
#   'befriends',
#   'freethinking',
#   'young',
#   'woman',
#   'next',
#   'door'],
#  ['new',
#   'york',
#   'cop',
#   'wife',
#   'go',
#   'european',
#   'vacation',
#   'reinvigorate',
#   'spark',
#   'marriage',
#   'end',
#   'getting',
#   'framed',
#   'run',
#   'death',
#   'elderly',
#   'billionaire'],
#  ['awakening',
#   'four',
#   'year',
#   'coma',
#   'former',
#   'assassin',
#   'wreaks',
#   'vengeance',
#   'team',
#   'assassins',
#   'betrayed',
#   'her'],
#  ['summer',
#   '1962',
#   'new',
#   'kid',
#   'town',
#   'taken',
#   'wing',
#   'young',
#   'baseball',
#   'prodigy',
#   'rowdy',
#   'team',
#   'resulting',
#   'many',
#   'adventures'],
#  ['intelligent',
#   'high',
#   'school',
#   'student',
#   'goes',
#   'secret',
#   'crusade',
#   'eliminate',
#   'criminals',
#   'world',
#   'discovering',
#   'notebook',
#   'capable',
#   'killing',
#   'anyone',
#   'whose',
#   'name',
#   'written',
#   'it'],
#  ['retired',
#   'orchestra',
#   'conductor',
#   'vacation',
#   'daughter',
#   'film',
#   'director',
#   'best',
#   'friend',
#   'alps',
#   'receives',
#   'invitation',
#   'queen',
#   'elizabeth',
#   'ii',
#   'perform',
#   'prince',
#   'philip',
#   's',
#   'birthday'],
#  ['16',
#   'year',
#   'old',
#   'daughter',
#   'goes',
#   'missing',
#   'desperate',
#   'father',
#   'breaks',
#   'laptop',
#   'look',
#   'clues',
#   'find',
#   'her'],
#  ['43',
#   'ad',
#   'roman',
#   'army',
#   'returns',
#   'crush',
#   'celtic',
#   'heart',
#   'britannia'],
#  ['armed',
#   'super',
#   'suit',
#   'astonishing',
#   'ability',
#   'shrink',
#   'scale',
#   'increase',
#   'strength',
#   'cat',
#   'burglar',
#   'scott',
#   'lang',
#   'must',
#   'embrace',
#   'inner',
#   'hero',
#   'help',
#   'mentor',
#   'dr',
#   'hank',
#   'pym',
#   'plan',
#   'pull',
#   'heist',
#   'save',
#   'world'],
#  ['woman',
#   'leaves',
#   'austrian',
#   'convent',
#   'become',
#   'governess',
#   'children',
#   'naval',
#   'officer',
#   'widower'],
#  ['attack',
#   'u',
#   's',
#   'compound',
#   'libya',
#   'security',
#   'team',
#   'struggles',
#   'make',
#   'sense',
#   'chaos'],
#  ['oakland',
#   'a',
#   's',
#   'general',
#   'manager',
#   'billy',
#   'beane',
#   's',
#   'successful',
#   'attempt',
#   'assemble',
#   'baseball',
#   'team',
#   'lean',
#   'budget',
#   'employing',
#   'computer',
#   'generated',
#   'analysis',
#   'acquire',
#   'new',
#   'players'],
#  ['victor',
#   'new',
#   'student',
#   'creekwood',
#   'high',
#   'school',
#   'journey',
#   'self',
#   'discovery',
#   'facing',
#   'challenges',
#   'home',
#   'adjusting',
#   'new',
#   'city',
#   'struggling',
#   'sexual',
#   'orientation'],
#  ['complicated',
#   'life',
#   'modern',
#   'day',
#   'first',
#   'generation',
#   'indian',
#   'american',
#   'teenage',
#   'girl',
#   'inspired',
#   'mindy',
#   'kaling',
#   's',
#   'childhood'],
#  ['reunited',
#   'death',
#   'college',
#   'friend',
#   'three',
#   'divorced',
#   'women',
#   'seek',
#   'revenge',
#   'husbands',
#   'left',
#   'younger',
#   'women'],
#  ['nomi',
#   'young',
#   'drifter',
#   'arrives',
#   'las',
#   'vegas',
#   'become',
#   'dancer',
#   'soon',
#   'sets',
#   'clawing',
#   'pushing',
#   'way',
#   'become',
#   'top',
#   'vegas',
#   'showgirls'],
#  ['lives',
#   'kids',
#   'degrassi',
#   'community',
#   'school',
#   'dealing',
#   'serious',
#   'sometimes',
#   'taboo',
#   'issues',
#   'plague',
#   'teenagers'],
#  ['fearing',
#   'actions',
#   'superman',
#   'left',
#   'unchecked',
#   'batman',
#   'takes',
#   'man',
#   'steel',
#   'world',
#   'wrestles',
#   'kind',
#   'hero',
#   'really',
#   'needs'],
#  ['frustrated',
#   'son',
#   'tries',
#   'determine',
#   'fact',
#   'fiction',
#   'dying',
#   'father',
#   's',
#   'life'],
#  ['political',
#   'involvement',
#   'avengers',
#   'affairs',
#   'causes',
#   'rift',
#   'captain',
#   'america',
#   'iron',
#   'man'],
#  ['graduating',
#   'emory',
#   'university',
#   'top',
#   'student',
#   'athlete',
#   'christopher',
#   'mccandless',
#   'abandons',
#   'possessions',
#   'gives',
#   'entire',
#   '24',
#   '000',
#   'savings',
#   'account',
#   'charity',
#   'hitchhikes',
#   'alaska',
#   'live',
#   'wilderness',
#   'along',
#   'way',
#   'christopher',
#   'encounters',
#   'series',
#   'characters',
#   'shape',
#   'life'],
#  ['human', 'stories', 'sides', 'israel', 'palestine', 'conflict'],
#  ['couple',
#   's',
#   'relationship',
#   'tested',
#   'uninvited',
#   'guests',
#   'arrive',
#   'home',
#   'disrupting',
#   'tranquil',
#   'existence'],
#  ['soldier',
#   'fighting',
#   'aliens',
#   'gets',
#   'relive',
#   'day',
#   'again',
#   'day',
#   'restarting',
#   'every',
#   'time',
#   'dies'],
#  ['el',
#   'camino',
#   'breaking',
#   'bad',
#   'movie',
#   'follows',
#   'fugitive',
#   'jesse',
#   'pinkman',
#   'runs',
#   'captors',
#   'law',
#   'past'],
#  ['streetwise',
#   'hustler',
#   'pulled',
#   'compelling',
#   'conspiracy',
#   'witnessing',
#   'suicide',
#   'girl',
#   'looks',
#   'like',
#   'her'],
#  ['manipulative',
#   'woman',
#   'roguish',
#   'man',
#   'conduct',
#   'turbulent',
#   'romance',
#   'american',
#   'civil',
#   'war',
#   'reconstruction',
#   'periods'],
#  ['archaeological',
#   'dig',
#   'ancient',
#   'city',
#   'hamunaptra',
#   'american',
#   'serving',
#   'french',
#   'foreign',
#   'legion',
#   'accidentally',
#   'awakens',
#   'mummy',
#   'begins',
#   'wreck',
#   'havoc',
#   'searches',
#   'reincarnation',
#   'long',
#   'lost',
#   'love'],
#  ['year',
#   'disposing',
#   'body',
#   'man',
#   'accidentally',
#   'killed',
#   'group',
#   'dumb',
#   'teenagers',
#   'stalked',
#   'bumbling',
#   'serial',
#   'killer'],
#  ['life',
#   'trials',
#   '1930s',
#   '1940s',
#   'virginia',
#   'mountain',
#   'family',
#   'financial',
#   'depression',
#   'world',
#   'war',
#   'ii'],
#  ['retiring',
#   'assassin',
#   'suddenly',
#   'finds',
#   'receiving',
#   'end',
#   'hit',
#   'contracted',
#   'none',
#   'employer',
#   'seeking',
#   'cash',
#   'pensions',
#   'aging',
#   'employees'],
#  ['hot',
#   'shot',
#   'race',
#   'car',
#   'named',
#   'lightning',
#   'mcqueen',
#   'gets',
#   'waylaid',
#   'radiator',
#   'springs',
#   'finds',
#   'true',
#   'meaning',
#   'friendship',
#   'family'],
#  ['star',
#   'pilot',
#   'sidekick',
#   'must',
#   'come',
#   'rescue',
#   'princess',
#   'save',
#   'galaxy',
#   'ruthless',
#   'race',
#   'beings',
#   'known',
#   'spaceballs'],
#  ['small',
#   'time',
#   'rancher',
#   'agrees',
#   'hold',
#   'captured',
#   'outlaw',
#   'who',
#   's',
#   'awaiting',
#   'train',
#   'go',
#   'court',
#   'yuma',
#   'battle',
#   'wills',
#   'ensues',
#   'outlaw',
#   'tries',
#   'psych',
#   'rancher'],
#  ['a',
#   'father',
#   's',
#   'love',
#   'save',
#   'life',
#   'take',
#   'one',
#   'sets',
#   'tone',
#   'dark',
#   'gritty',
#   'series'],
#  ['biologist',
#   'signs',
#   'dangerous',
#   'secret',
#   'expedition',
#   'mysterious',
#   'zone',
#   'laws',
#   'nature',
#   'apply'],
#  ...]

# %% [raw]
# Training our corpus with Google's pre-trained Word2Vec model.

# %%
# mount Google Drive to Colab session
from google.colab import drive
drive.mount('/content/drive')

# copy to session drive ('/content')
# !cp -r /content/drive/MyDrive/GoogleNews-vectors-negative300.bin /content

# load word2vec model
import os
gn_vec_path = os.path.abspath(os.getcwd()) + "/" + "GoogleNews-vectors-negative300.bin"

from gensim.models import Word2Vec, KeyedVectors
google_word2vec = KeyedVectors.load_word2vec_format(gn_vec_path, binary=True) #load the model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Training our corpus with the model
google_model = Word2Vec(vector_size = 300, window = 5, min_count = 2, workers = -1)
google_model.build_vocab(corpus)
google_model.wv.vectors_lockf = np.ones(len(google_model.wv))

google_model.wv.intersect_word2vec_format(gn_vec_path, lockf = 1.0, binary = True)
google_model.train(corpus, total_examples = google_model.corpus_count, epochs = 5)
# Out:
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (0) did not equal expected count (10000)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (0) did not equal expected count (10000)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (0) did not equal expected count (10000)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (0) did not equal expected count (10000)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (0) did not equal expected count (10000)
# (0, 0)

# %% [raw]
# We will create a function called vectors for generating average Word2Vec embeddings and storing them as a list called 'word_embeddings'.

# %%
def vectors(x):

    # Creating a list for storing the vectors ('Description' into vectors)
    global word_embeddings
    word_embeddings = []

    # Reading the each 'Description'
    for line in df['Cleaned']:
        avgword2vec = None
        count = 0
        for word in line.split():
            if word in google_model.wv.key_to_index:
                count += 1
                if avgword2vec is None:
                    avgword2vec = google_model.wv[word]
                else:
                    avgword2vec = avgword2vec + google_model.wv[word]

        if avgword2vec is not None:
            avgword2vec = avgword2vec / count
            word_embeddings.append(avgword2vec)

# %% [raw]
# ### Top 5 Recommendations using Average Word2vec

# %%
# Recommending the Top 5 similar movies
def recommendations(movie):
    # Calling the function vectors
    vectors(df)
    # Finding cosine similarity for the vectors
    cosine_similarities = cosine_similarity(word_embeddings, word_embeddings)
    # Taking the Title and Movie Image Link and store in new dataframe called 'movies'
    movies = df[['Movie', 'ImgLink']]

    # Reverse mapping of the index
    indices = pd.Series(df.index, index = df['Movie']).drop_duplicates()

    idx = indices[movie]
    sim_scores = list(enumerate(cosine_similarities[idx]))
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
    sim_scores = sim_scores[1:6]
    movie_indices = [i[0] for i in sim_scores]
    recommend = movies.iloc[movie_indices]

    for index, row in recommend.iterrows():
        response = requests.get(row['ImgLink'])
        img = Image.open(BytesIO(response.content))
        plt.figure()
        plt.imshow(img)
        plt.title(row['Movie'])

# %% [markdown]
# Let's get recommendations based on the movie 'Dil Bechara'.

# %%
recommendations('Dil Bechara')

# %% [markdown]
# *This movie belongs to "**Romance/Drama**" genre and it recommends similar kinds of movies.*

# %% [markdown]
# Now, let's get a recommendation on the movie 'Avengers: Endgame'.

# %%
recommendations('Avengers: Endgame')

# %% [raw]
# *This movie belongs to "**Action**" genre and it also recommends similar kinds of movies including **Guardians of the Galaxy** & **Avengers: Infinity War** which belongs to the same cinematic universe.*

# %% [raw]
# ---

# %% [raw]
# ## TF-IDF Word2Vec Model
#
# We will use the same corpus, with the only change being in the word embeddings.

# %%
# Building the TF-IDF model and calculating the TF-IDF score
tfidf = TfidfVectorizer(analyzer = 'word', ngram_range = (1, 3), min_df = 5, stop_words = 'english')
# tfidf_vectors = tfidf.fit(df['Cleaned'])
tfidf_vectors = tfidf.fit_transform(df['Cleaned'])

# Getting the words from the TF-IDF model
tfidf_list = dict(zip(tfidf.get_feature_names_out(), list(tfidf.idf_)))

# TF-IDF words/column names
tfidf_feature = tfidf.get_feature_names_out()

# %% [raw]
# ### Building TF-IDF Word2vec Embeddings

# %% [raw]
# # Storing the TFIDF Word2Vec embeddings
# tfidf_vectors = []
# line = 0
#
# # For each 'Description'
# for desc in corpus:
#
#     # Word vectors are of zero length (using 300 dimensions)
#     sent_vec = np.zeros(300)
#
#     # Number of words with a valid vector in the 'Description'
#     weight_sum =0;
#
#     # For each word in the 'Description'
#     for word in desc:
#         if word in google_model.wv.vocab and word in tfidf_feature:
#             vec = google_model.wv[word]
#             tf_idf = tfidf_list[word] * (desc.count(word) / len(desc))
#             sent_vec += (vec * tf_idf)
#             weight_sum += tf_idf
#     if weight_sum != 0:
#         sent_vec /= weight_sum
#     tfidf_vectors.append(sent_vec)
#     line += 1

# %% [markdown]
# ### Top 5 Recommendation using TF-IDF Word2vec

# %%
# Recommending top 5 similar movies
def recommendations_2(movie):

    # Finding cosine similarity for the vectors
    cosine_similarities = cosine_similarity(tfidf_vectors,  tfidf_vectors)

    # Taking the Title and Image Link and store in new data frame called movies
    movies = df[['Movie', 'ImgLink']]

    # Reverse mapping of the index
    indices = pd.Series(df.index, index = df['Movie']).drop_duplicates()

    idx = indices[movie]
    sim_scores = list(enumerate(cosine_similarities[idx]))
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
    sim_scores = sim_scores[1:6]
    movie_indices = [i[0] for i in sim_scores]
    recommend = movies.iloc[movie_indices]
    for index, row in recommend.iterrows():

        response = requests.get(row['ImgLink'])
        img = Image.open(BytesIO(response.content))
        plt.figure()
        plt.imshow(img)
        plt.title(row['Movie'])

# %% [raw]
# Once again, let's get recommendations based on the movie 'Dil Bechara'.

# %%
recommendations_2('Dil Bechara')

# %% [markdown]
# *The recommendations this time are a bit different & only two movies are common recommendations in both the outputs. But, the newly recommended movies also belong to a similar genre.*

# %% [markdown]
# Now, let's try to generate recommendations for a horror movie 'The Conjuring'.

# %%
recommendations_2('The Conjuring')

# %% [markdown]
# *We can clearly see that our recommendation engine recommends other Horror movies based on the movie 'The Conjuring'.*
